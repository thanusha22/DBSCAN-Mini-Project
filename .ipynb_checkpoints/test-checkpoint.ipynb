# %%
import copy
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pylab
import math
from itertools import product
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import time
import sys
start_time = time.time()
import decimal
import scipy.spatial as spatial
from collections import Counter
import itertools
import sys
sys.setrecursionlimit(1000)
epsilon = 1.8
min_points =  4.0  # float(sys.argv[3])


# points,neighbours,merging distance,position,flag,cluster_id,hot_cold,visited
def supercube_dbscan():
    # Take input from file (Copy Paste from dbscan code) and sort acc. to x and  y axis
    # open the dataset
    file_name = "dataset1.csv"
    i = open(file_name)
    lines = i.read().strip().split('\n')
    i.close()
    # initialize the list in which your dataset will be stored in the form of list
    dataset = {}
    coord = []
    dim_size = 2  # int(sys.argv[1]) #float(sys.argv[2])
    min_points = 4.0  # float(sys.argv[3])
    # Sort
    for i in range(dim_size):
        coord.append([])
    for i in lines:
        line = i.rstrip().split(',')
        temp = []
        # extract x and y coordinates
        for j in line:
            temp.append(j.strip())
        # print temp
        # convert to float if the input is not numeric type
        for i in range(dim_size):
            temp[i] = float(temp[i])
            coord[i].append(round(temp[i],2))
        # can't use list as keys so converting to tuple
        temp = tuple(temp)
        # print len(dataset)
        # default not visited that's why 0
        dataset[temp] = 0
    data = list(sorted(dataset.keys(), key=lambda t: t[0]))
    data = re_round(data)
    #print data
    start_box_coord = []
    start_box_coord.append(round(min(coord[0]), 2))  # left most point in dataset(0)
    start_box_coord.append(round(max(coord[0]), 2))  # right most point in dataset(1)
    start_box_coord.append(round(max(coord[1]), 2))  # top most point in dataset(2)
    start_box_coord.append(round(min(coord[1]), 2))  # bottom most point in dataset(3)
    print("start_box_coord",start_box_coord)
    len_x = round(abs(start_box_coord[1] - start_box_coord[0]), 2)  # total length of x-axis
    len_y = round(abs(start_box_coord[2] - start_box_coord[3]), 2)
    # total length of y-axis
    number_box_x = int(math.ceil(len_x / round((epsilon / 1.41), 2)))  # epsilon/rt(2)=1.27
    number_box_y = int(math.ceil(len_y / round((epsilon / 1.41), 2)))
    len_x = number_box_x * round(epsilon / 1.41, 2)
    len_y = number_box_y * round(epsilon / 1.41, 2)
    #print round(epsilon / 1.41, 2)
    # len_x,len_y
    print("Graph for visualization of clusters formed: ")
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(coord[0], coord[1], cmap=plt.hot())
    plt.plot([start_box_coord[0],start_box_coord[1],start_box_coord[1],start_box_coord[0],start_box_coord[0]], [start_box_coord[2],start_box_coord[2],start_box_coord[3],start_box_coord[3],start_box_coord[2]], 'r-')
    plt.show()
    no_k_bands = number_box_x
    no_l_bands = number_box_y
    k_bands = []
    l_bands = []
    k_bands.append(round(start_box_coord[0] + round(epsilon / 1.41, 2),2))
    l_bands.append(round(start_box_coord[3] + round(epsilon / 1.41, 2),2))
    for i in range(1, no_k_bands):
        temp = k_bands[i - 1] + round((epsilon / 1.41), 2)
        #print temp
        k_bands.append(round(temp, 2))
    for j in range(1, no_l_bands):
        temp1 = l_bands[j - 1] + round((epsilon / 1.41), 2)
        #print temp1
        l_bands.append(round(temp1, 2))
    #print k_bands,l_bands
    # creating the boxes
    box_list = list(itertools.product(k_bands, l_bands))
    # print box_list
    # print(len(box_list))
    # 0 for corner,1 for edge,2 for middle
    box_details = {}
    merge_points = []
    open_flag = 0
    cluster_id = 0
    hot_cold = 0
    visited=0
    for i in range(8):
        merge_points.append((-999, -999))
    box_start_coord = []
    box_start_coord.append(k_bands[0])
    box_start_coord.append(k_bands[number_box_x - 1])
    box_start_coord.append(l_bands[number_box_y - 1])
    box_start_coord.append(l_bands[0])
    print("box_start_coord",box_start_coord)
    # print start_box_coord
    for n in box_list:
        # print n
        if (n[0] == box_start_coord[0] or n[0] == box_start_coord[1] or n[1] == box_start_coord[2] or n[1] ==
            box_start_coord[3]):
            # corner cases
            #print("###################################################################")
            if ((n[0] == box_start_coord[0] and n[1] == box_start_coord[2])):
                # print "______________________________________________________"
                neighbour = re_round([(n[0] + round((epsilon / 1.41), 2), n[1]), (
                n[0] + round((epsilon / 1.41), 2), n[1] + round((epsilon / 1.41), 2)),
                                      (n[0], n[1] + round((epsilon / 1.41), 2))])
                box_details[n] = [[], neighbour, merge_points, 0, open_flag, cluster_id,
                                  hot_cold,visited]  # points,neighbours,merging distance,position,flag,cluster_id,hot_cold
            elif ((n[0] == box_start_coord[1] and n[1] == box_start_coord[2])):
                #print("++++++++++++++++++++++++++++++++++++++++++++++++++++++")
                neighbour = re_round([(n[0] - round((epsilon / 1.41), 2), n[1]), (
                n[0] - round((epsilon / 1.41), 2), n[1] - round((epsilon / 1.41), 2)),
                                      (n[0], n[1] - round((epsilon / 1.41), 2))])
                box_details[n] = [[], neighbour, merge_points, 0, open_flag, cluster_id, hot_cold,visited]
            elif ((n[0] == box_start_coord[1] and n[1] == box_start_coord[3])):
                #print("&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&")
                neighbour = re_round([(n[0], n[1] + round((epsilon / 1.41), 2)),
                                      (n[0] - round((epsilon / 1.41), 2), n[1]), (
                                      n[0] - round((epsilon / 1.41), 2),
                                      n[1] + round((epsilon / 1.41), 2))])
                box_details[n] = [[], neighbour, merge_points, 0, open_flag, cluster_id, hot_cold,visited]
            elif ((n[0] == box_start_coord[0] and n[1] == box_start_coord[3])):
                print("-------------------------------------------------------")
                neighbour = re_round([(n[0], n[1] + round((epsilon / 1.41), 2)), (
                n[0] + round((epsilon / 1.41), 2), n[1] + round((epsilon / 1.41), 2)),
                                      (n[0] + round((epsilon / 1.41), 2), n[1])])
                box_details[n] = [[], neighbour, merge_points, 0, open_flag, cluster_id, hot_cold,visited]
            else:  # edge case
                if (n[0] == box_start_coord[0]):  # left side
                    neighbour = re_round([(n[0], n[1] + round((epsilon / 1.41), 2)), (
                    n[0] - round((epsilon / 1.41), 2), n[1] + round((epsilon / 1.41), 2)),
                                          (n[0] - round((epsilon / 1.41), 2), n[1]), (
                                          n[0] - round((epsilon / 1.41), 2),
                                          n[1] - round((epsilon / 1.41), 2)),
                                          (n[0], n[1] - round((epsilon / 1.41), 2))])
                    box_details[n] = [[], neighbour, merge_points, 1, open_flag, cluster_id, hot_cold,visited]
                elif (n[1] == box_start_coord[2]):  # top side
                    neighbour = re_round([(n[0] - round((epsilon / 1.41), 2), n[1]), (
                    n[0] - round((epsilon / 1.41), 2), n[1] - round((epsilon / 1.41), 2)),
                                          (n[0], n[1] - round((epsilon / 1.41), 2)), (
                                          n[0] + round((epsilon / 1.41), 2),
                                          n[1] - round((epsilon / 1.41), 2)),
                                          (n[0] + round((epsilon / 1.41), 2), n[1])])
                    box_details[n] = [[], neighbour, merge_points, 1, open_flag, cluster_id, hot_cold,visited]
                elif (n[0] == box_start_coord[1]):  # right side
                    # print "jinesh"
                    neighbour = re_round([(n[0], n[1] + round((epsilon / 1.41), 2)),
                                          (n[0], n[1] - round((epsilon / 1.41), 2)), (
                                          n[0] - round((epsilon / 1.41), 2),
                                          n[1] + round((epsilon / 1.41), 2)),
                                          (n[0] - round((epsilon / 1.41), 2), n[1]), (
                                          n[0] - round((epsilon / 1.41), 2),
                                          n[1] - round((epsilon / 1.41), 2))])
                    box_details[n] = [[], neighbour, merge_points, 1, open_flag, cluster_id, hot_cold,visited]
                else:  # bottom side
                    # print "jinesh"
                    neighbour = re_round([(n[0] - round((epsilon / 1.41), 2), n[1]),
                                          (n[0] + round((epsilon / 1.41), 2), n[1]),
                                          (n[0], n[1] + round((epsilon / 1.41), 2)), (
                                          n[0] - round((epsilon / 1.41), 2),
                                          n[1] + round((epsilon / 1.41), 2)), (
                                          n[0] + round((epsilon / 1.41), 2),
                                          n[1] + round((epsilon / 1.41), 2))])
                    box_details[n] = [[], neighbour, merge_points, 1, open_flag, cluster_id, hot_cold,visited]
        else:
            neighbour = re_round(
                [(n[0] - round((epsilon / 1.41), 2), n[1] + round((epsilon / 1.41), 2)),
                 (n[0], n[1] + round((epsilon / 1.41), 2)),
                 (n[0] + round((epsilon / 1.41), 2), n[1] + round((epsilon / 1.41), 2)),
                 (n[0] - round((epsilon / 1.41), 2), n[1]), (n[0] + round((epsilon / 1.41), 2), n[1]),
                 (n[0] - round((epsilon / 1.41), 2), n[1] - round((epsilon / 1.41), 2)),
                 (n[0], n[1] - round((epsilon / 1.41), 2)),
                 (n[0] + round((epsilon / 1.41), 2), n[1] - round((epsilon / 1.41), 2))])
            box_details[n] = [[], neighbour, merge_points, 2, open_flag, cluster_id, hot_cold,visited]
    # for i in box_details.keys():
    #    print i," ke neighbours hai ---> ",box_details[i][1]
    '''k_bands.append(3.13)
    l_bands.append(3.07)
    v=list ( itertools.product(k_bands,l_bands) )
    print v
    l=[]
    p=[]
    for i in v:
        l.append(i[0])
        p.append(i[1])
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(coord[0], coord[1], cmap=plt.hot())
    plt.plot(l,p,'go')
    plt.show()'''
    count = 0
    print(box_details)
    for j in data:
        # print j
        count = count + 1
        # print coun
        # check for mode over here
        p = (j[0] - start_box_coord[0])
        q = (j[1] - start_box_coord[3])
        if p == 0:
            p = 1
        elif q == 0:
            q = 1
        else:
            p = p
            q = q
        mov_x = math.ceil(p / round((epsilon / 1.41), 2))
        mov_y = math.ceil(q / round((epsilon / 1.41), 2))
        a = (mov_x * round((epsilon / 1.41), 2)) + start_box_coord[0]
        #print a
        b = (mov_y * round((epsilon / 1.41), 2)) + start_box_coord[3]
        #print b
        a = re_round(a)
        b = re_round(b)
        #print  "point :", j
        #print "box:",a,b
        tp = box_details[a, b][0]
        # print "points already present:",tp
        check = box_details[a, b][4]
        # print "already visited:",check
        # print "box contents:",box_details
        if (not check):
            # print (a,b),j
            box_details[a, b][4] = 1
            list_t = []
            for _ in range(8):
                list_t.append(j)
            box_details[a, b][2] = copy.deepcopy(list_t)
        else:
            top_id=(a-round((epsilon / (2*1.41)), 2),b)
            bottom_id=(a-round((epsilon / (2*1.41)), 2),b-round((epsilon / 1.41), 2))
            left_id=(a-round((epsilon / (1.41)), 2),b-round((epsilon / (2*1.41)), 2))
            right_id=(a,b-round((epsilon / (2*1.41)), 2))
            lefttop_id=(a-round((epsilon / 1.41), 2),b)
            righttop_id=(a,b)
            leftbottom_id=(a-round((epsilon / 1.41), 2),b-round((epsilon / 1.41), 2))
            rightbottom_id=(a,b-round((epsilon / 1.41), 2))
            lefttop_d=euclidean(lefttop_id,box_details[a, b][2][0])
            top_d=euclidean(top_id,box_details[a, b][2][1])
            righttop_d=euclidean(righttop_id,box_details[a, b][2][2])
            left_d=euclidean(left_id,box_details[a, b][2][3])
            right_d=euclidean(right_id,box_details[a, b][2][4])
            leftbottom_d=euclidean(leftbottom_id,box_details[a, b][2][5])
            bottom_d=euclidean(bottom_id,box_details[a, b][2][6])
            rightbottom_d=euclidean(rightbottom_id,box_details[a, b][2][7])
            new_lefttop_d=euclidean(lefttop_id,j)
            new_top_d=euclidean(top_id,j)
            new_righttop_d=euclidean(righttop_id,j)
            new_left_d=euclidean(left_id,j)
            new_right_d=euclidean(right_id,j)
            new_leftbottom_d=euclidean(leftbottom_id,j)
            new_bottom_d=euclidean(bottom_id,j)
            new_rightbottom_d=euclidean(rightbottom_id,j)
            #print j,a, b, top_d, new_top_d,box_details[a, b][2][1],top_id
            if(lefttop_d>new_lefttop_d):
                #print a,b,lefttop_d,new_lefttop_d
                box_details[a, b][2][0]=j
            if(top_d>new_top_d):
                #print a,b,top_d,new_top_d
                box_details[a, b][2][1]=j
            if(righttop_d>new_righttop_d):
                box_details[a, b][2][2]=j
            if(leftbottom_d>new_leftbottom_d):
                box_details[a, b][2][5]=j
            if(left_d>new_left_d):
                box_details[a, b][2][3]=j
            if(right_d>new_right_d):
                box_details[a, b][2][4]=j
            if(bottom_d>new_bottom_d):
                box_details[a, b][2][6]=j
            if(rightbottom_d>new_rightbottom_d):
                box_details[a, b][2][7]=j
            '''
            if (j[0] < box_details[a, b][2][3][0]):
                box_details[a, b][2][3] = j
            else:
                left_a = (a - round((epsilon / 1.41), 2), b / 2)
                i = box_details[a, b][2][3]
                temp1 = euclidean(j, left_a)
                temp2 = euclidean(i, left_a)

                if(temp1>temp2):
                    box_details[a, b][2][3]=i
                else:
                    box_details[a, b][2][3]=j
            if (j[0] > box_details[a, b][2][4][0]):
                box_details[a, b][2][4] = j
            else:
                right_a = (a, b / 2)
                i = box_details[a, b][2][4]
                temp1 = euclidean(j, right_a)
                temp2 = euclidean(i, right_a)
                if (temp1 > temp2):
                    box_details[a, b][2][4] = i
                else:
                    box_details[a, b][2][4] = j
            if (j[1] > box_details[a, b][2][1][1]):
                box_details[a, b][2][1] = j
            else:
                top_a = (a / 2, b)
                i=box_details[a, b][2][1]
                temp1=euclidean(j,top_a)
                temp2=euclidean(i,top_a)
                if (temp1 > temp2):
                    box_details[a, b][2][1] = i
                else:
                    box_details[a, b][2][1] = j
            if (j[1] < box_details[a, b][2][6][1]):
                box_details[a, b][2][6] = j
            else:
                bottom_a=(a/2,b-round((epsilon / 1.41), 2))
                i=box_details[a, b][2][6]
                temp1=euclidean(j,bottom_a)
                temp2=euclidean(i,bottom_a)
                if (temp1 > temp2):
                    box_details[a, b][2][6] = i
                else:
                    box_details[a, b][2][6] = j
            if (j[0]) <= (box_details[a, b][2][0][0]) and (j[1] >= box_details[a, b][2][0][1]):
                box_details[a, b][2][0] = j
            if j[0] >= box_details[a, b][2][2][0] and j[1] >= box_details[a, b][2][2][1]:
                box_details[a, b][2][2] = j
            if (j[0] <= box_details[a, b][2][5][0] and j[1] <= box_details[a, b][2][5][1]):
                box_details[a, b][2][5] = j
            if (j[0] >= box_details[a, b][2][7][0] and j[1] <= box_details[a, b][2][7][1]):
                box_details[a, b][2][7] = j

            '''
            '''
            #print box_details[a,b][2][0]
            box_details[a,b][2][1]=j
            box_details[a,b][2][2]=j
            box_details[a,b][2][3] = j
            box_details[a,b][2][4] = j
            box_details[a,b][2][5] = j
            box_details[a,b][2][6] = j
            box_details[a,b][2][7] = j
            check=0
            '''
        # print tp
        # print "box contents:",box_details
        # print "merging points:",box_details[a,b][2]
        tp.append(j)
        # print "current points:",tp
        box_details[a, b][0] = tp
        # print "points in box:",box_details[a,b][0]
        # print "box contents:",box_details
    #print box_details
    # print data
    # for i in box_details.keys():
    # print i,box_details[i][0]
    # 0=cold
    #cluster_id=count
    count = 1
    hot=1
    #print box_details
    for i in box_details.keys():
        print("Current Box:", i)
        if(not box_details[i][7] and box_details[i][4]):

            box_details[i][6]=1#sabko kyu hot karna hai intially ek ko ho hot karo??
            box_details[i][5] = count#do we need for every box
            print("Cluster_id before calling clustering on box ",i,":",box_details[i][5])

            clustering(box_details, i)
            count = count + 1
    #print box_details
    cluster_list=[]
    cluster_points={}
    for i in box_details.keys():
        cluster_number=box_details[i][5]
        points=box_details[i][0]
        #print cluster_number
        #print points
        if cluster_number not in cluster_points.keys():
            cluster_points[cluster_number]=points
            #print "if :",cluster_points
        else:
            #print "else :",cluster_points
            if cluster_number!=0:
                already_present=cluster_points[cluster_number]
                #print already_present
                already_present.extend(points)
                cluster_points[cluster_number]=already_present
                #print "else if :",cluster_points

            else:
                pass
        cluster_list.append(cluster_number)
    print(cluster_points)
    for i in cluster_points.keys():
        print("Cluster_ID :",i)
        print("Points :",cluster_points[i])
        print("No. of points :",len(cluster_points[i]))
    print("Accuracy: ",i/len(cluster_points))
    print(Counter(cluster_list))
    print("--- %s seconds in super_cube dbscan---" % (time.time() - start_time))
    



def clustering(box_details, i):
    visited=box_details[i][7]
    flag=False
    if(not visited):
        box_details[i][7]=1
        open_flag = box_details[i][4]
        hot_flag = box_details[i][6]
        print("Flag details before checking flag ",open_flag,hot_flag)
        if (open_flag and hot_flag):
            print("Inside first if")
            # Checking for top box
            j = (round(i[0],2), round(i[1] + round(epsilon / 1.41, 2),2))
            print("First level top box",j)
            if (j in box_details.keys()):
                if( not box_details[j][7] and box_details[j][4]):
                    flag = check_up(i, box_details, j)
                    print("To merge or not to merge first level top box",flag)
                    if (flag):
                        box_details[j][6] = 1  # hot
                        box_details[j][5] = box_details[i][5]
                        print("Calling clustering on 1st level top box",j,box_details[i][5])
                        clustering(box_details, j)

                if(not flag or box_details[j][7] or not box_details[j][4]):
                    # checking for j+1
                    print("Calling for Second level for top box")
                    jplus1 = (round(j[0],2), round(j[1] + round(epsilon / 1.41, 2),2))
                    if (jplus1 in box_details.keys()):
                        if (box_details[jplus1][4] and not box_details[jplus1][7]):
                            print("Second Level box:",jplus1)
                            flag = check_up(j, box_details, jplus1)
                            print("To merge or not to merge second level top box",flag)
                            if (flag):
                                box_details[jplus1][6] = 1  # hot
                                box_details[jplus1][5] = box_details[j][5]
                                print("New cluster_id for top box jplus1",jplus1,box_details[jplus1][5])
                                print("Calling clustering on top box second level")
                                clustering(box_details, jplus1)

            # Checking for up right
            print("checking for top right 1st  level box ")
            j = (round(i[0] + round(epsilon / 1.41, 2),2), round(i[1] + round(epsilon / 1.41, 2),2))
            print("1st level top right level = ",j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):
                    flag = check_up_right(i, box_details, j)
                    print("To merge or not to merge top right level ", flag)
                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st top right box",box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                '''if(not flag or box_details[j][7] or not box_details[j][4]):
                    # checking for j+1
                    print "Calling for Second level for top right"
                    jplus1 = (round(j[0] + round(epsilon / 1.41, 2),2), round(j[1] + round(epsilon / 1.41, 2),2))
                    print "choosing 2nd level box top right", jplus1
                    if (jplus1 in box_details.keys()):
                        if (box_details[jplus1][4] and not box_details[jplus1][7]):
                            print "Second Level box:", jplus1
                            flag = check_up_right(j, box_details, jplus1)
                            print "To merge or not to merge second level top right ",flag
                            if (flag):
                                box_details[jplus1][6] = 1
                                box_details[jplus1][5] = box_details[j][5]
                                print "New cluster_id for up right box jplus1",jplus1,box_details[jplus1][5]
                                print "Calling clustering on top right box second level"
                                clustering(box_details, jplus1)'''

            # Checking for right
            print("checking for right 1st  level box ")
            j = (round(i[0] + round(epsilon / 1.41, 2),2),round( i[1],2))
            print("1st level right level = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):

                    flag=check_right(i, box_details, j)
                    print("To merge or not to merge right level ", flag)
                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st right box",box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                if(not flag or box_details[j][7] or not box_details[j][4]):
                    print("Calling for Second level for  right")
                    jplus1 = (round(j[0] + round(epsilon / 1.41, 2),2), round(j[1],2))
                    print("choosing 2nd level box right", jplus1)
                    if (jplus1 in box_details.keys()):
                        if (box_details[jplus1][4] and not box_details[jplus1][7]):
                            print("Second Level box:", jplus1)
                            flag=check_right(j, box_details, jplus1)
                            print("To merge or not to merge second level right ", flag)
                            if (flag):
                                box_details[jplus1][6] = 1
                                box_details[jplus1][5] = box_details[j][5]
                                print("New cluster_id for right box jplus1",jplus1,box_details[jplus1][5])
                                print("Calling clustering on right box second level")
                                clustering(box_details, jplus1)

            # Checking for down right
            print("checking for down right 1st  level box ")
            j = (round(i[0] + round(epsilon / 1.41, 2),2), round(i[1] - round(epsilon / 1.41, 2),2))
            print("1st level down right box = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):

                    flag=check_down_right(i, box_details, j)
                    print("To merge or not to merge  down right level ", flag)

                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st down right box",box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                '''if(not flag or box_details[j][7] or not box_details[j][4]):
                    print "Calling for Second level for down right"
                    # check for j+1
                    jplus1 = (round(j[0] + round(epsilon / 1.41, 2),2), round(j[1] - round(epsilon / 1.41, 2),2))
                    print "choosing 2nd level box down right", jplus1
                    if (jplus1 in box_details.keys()):
                        if (box_details[jplus1][4] and not box_details[jplus1][7]):
                            flag=check_down_right(j, box_details, jplus1)
                            if (flag):
                                box_details[jplus1][6] = 1
                                box_details[jplus1][5] = box_details[j][5]
                                print "New cluster_id for down right box jplus1",jplus1,box_details[jplus1][5]
                                print "Calling clustering on down right box second level"
                                clustering(box_details, jplus1)'''

            # Checking for down
            print("checking for down 1st  level box ")
            j = (round(i[0],2), round(i[1] - round(epsilon / 1.41, 2),2))
            print("1st level down level = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):
                    flag=check_down(i, box_details, j)
                    print("To merge or not to merge  down level ", flag)
                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st down box",box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                if(not flag or box_details[j][7] or not box_details[j][4]):
                    print("Calling for Second level for down ")
                    # check for j+1
                    jplus1 = (round(j[0],2), round(j[1] - round(epsilon / 1.41, 2),2))
                    print("choosing 2nd level box down", jplus1)
                    if (jplus1 in box_details.keys()):
                        if (box_details[jplus1][4] and not box_details[jplus1][7]):
                            flag=check_down(j, box_details, jplus1)
                            if (flag):
                                box_details[jplus1][6] = 1
                                box_details[jplus1][5] = box_details[j][5]
                                print("New cluster_id for down box jplus1",jplus1,box_details[jplus1][5])
                                print("Calling clustering on down box second level")
                                clustering(box_details, jplus1)

            # Checking for down left
            print("checking for left down 1st  level box ")
            j = (round(i[0] - round(epsilon / 1.41, 2),2), round(i[1] - round(epsilon / 1.41, 2),2))
            print("1st level down left box = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):

                    flag=check_down_left(i, box_details, j)
                    print("To merge or not to merge left down level  ", flag)

                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st down left box", box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                '''if(not flag or box_details[j][7] or not box_details[j][4]):
                    print "Calling for Second level for down left"
                    # check for j+1
                    jplus1 = (round(i[0] - round(epsilon / 1.41, 2),2),round( i[1] - round(epsilon / 1.41, 2),2))
                    print "choosing 2nd level box down left", jplus1
                    if (jplus1 in box_details.keys()):
                        if (box_details[jplus1][4] and not box_details[jplus1][7]):
                            flag=check_down_left(j, box_details, jplus1)
                            if (flag):
                                box_details[jplus1][6] = 1
                                box_details[jplus1][5] = box_details[j][5]
                                print "New cluster_id for down left box jplus1",jplus1,box_details[jplus1][5]
                                print "Calling clustering on down left box second level"
                                clustering(box_details, jplus1)'''

            # Checking for left
            print("checking for left 1st  level box ")
            j = (round(i[0] - round(epsilon / 1.41, 2),2),round( i[1],2))
            print("1st level left box = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):
                    flag=check_left(i, box_details, j)
                    print("To merge or not to merge left level  ", flag)
                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st left box", box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                if(not flag or box_details[j][7] or not box_details[j][4]):
                    print("Calling for Second level for left")
                    # check for j+1 box
                    jplus1 = (round(j[0] - round(epsilon / 1.41, 2),2), round(j[1],2))
                    print("choosing 2nd level box up left ", jplus1)
                    if (jplus1 in box_details.keys()):
                        if (box_details[jplus1][4] and not box_details[jplus1][7]):
                            flag=check_left(j, box_details, jplus1)
                            if (flag):
                                box_details[jplus1][6] = 1
                                box_details[jplus1][5] = box_details[j][5]
                                print("New cluster_id for left  box jplus1",jplus1,box_details[jplus1][5])
                                print("Calling clustering on left box second level")
                                clustering(box_details, jplus1)

            # checking for up left
            print("checking for up left 1st  level box ")
            j = (round(i[0] - round(epsilon / 1.41, 2),2), round(i[1] + round(epsilon / 1.41, 2),2))
            print("1st level up left box = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):
                    flag=check_up_left(i, box_details, j)
                    print("To merge or not to merge up left level  ", flag)
                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st top left box", box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                '''if(not flag or box_details[j][7] or not box_details[j][4]):
                    print "Calling for Second level for left up"
                    # check for j+1
                    jplus1 = (round(j[0] - round(epsilon / 1.41, 2),2), round(j[1] + round(epsilon / 1.41, 2),2))
                    print "choosing 2nd level box up left ", jplus1
                    if (jplus1 in box_details.keys()):
                        if (box_details[jplus1][4] and not box_details[jplus1][7]):
                            flag=check_up_left(j, box_details, jplus1)
                            if (flag):
                                box_details[jplus1][6] = 1
                                box_details[jplus1][5] = box_details[j][5]
                                print "New cluster_id for up left box jplus1",jplus1,box_details[jplus1][5]
                                print "Calling clustering on up left box second level"
                                clustering(box_details, jplus1)'''
    return

def check_up(box_coord, box_details, check_box):
    flag = False
    top = box_details[box_coord][2][1]
    print("top point of ",box_coord,":",top)
    bottom = box_details[check_box][2][6]
    print("bottom point of ",check_box, ":", bottom)
    #print top,bottom
    dist = euclidean(top,bottom)
    print("Distance between points:",dist)
    if (dist < epsilon):
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag


def check_up_right(box_coord, box_details, check_box):
    flag = False
    top_right = box_details[box_coord][2][2]  # add correct values
    print("top_right point of ", box_coord, ":", top_right)
    bottom_left = box_details[check_box][2][5]  # add correct values
    print("bottom_left point of ",check_box, ":", bottom_left)
    dist = euclidean(top_right,bottom_left)
    print("Distance between points:",dist)

    #print dist
    if (dist < epsilon ):
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag

def check_right(box_coord, box_details, check_box):
    flag = False
    right = box_details[box_coord][2][4]  # add correct values
    print("right point of ", box_coord, ":", right)
    left = box_details[check_box][2][3]  # add correct values
    print("left point of ", check_box, ":", left)

    dist = euclidean(right,left)
    print("Distance between points:",dist)

    #print dist
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
    if (dist < epsilon ):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag

def check_down_right(box_coord, box_details, check_box):
    flag = False
    bottom_right = box_details[box_coord][2][7]  # add correct values
    print("bottom_right point of ", box_coord, ":", bottom_right)
    top_left = box_details[check_box][2][0]  # add correct values
    print("top_left point of ", check_box, ":", top_left)
    dist=euclidean(bottom_right,top_left)
    print("Distance between points:",dist)

    if (dist < epsilon ):
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag

def check_down(box_coord, box_details, check_box):
    flag = False
    bottom = box_details[box_coord][2][6]  # add correct values
    print("bottom point of ", box_coord, ":", bottom)
    top = box_details[check_box][2][1]  # add correct values
    print("top point of ", check_box, ":", top)
    dist = euclidean(bottom,top)
    print("Distance between points:",dist)

    #print dist
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
    if (dist < epsilon ):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag

def check_down_left(box_coord, box_details, check_box):
    flag = False
    bottom_left = box_details[box_coord][2][5]  # add correct values
    print("bottom_left point of ", box_coord, ":", bottom_left)
    top_right = box_details[check_box][2][2]  # add correct values
    print("top_right point of ", check_box, ":", top_right)
    dist = euclidean(bottom_left,top_right)
    print("Distance between points:",dist)
    #print dist
    if (dist < epsilon ):
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
        flag = True
    print("Boxes to merge or not:",flag)

    return flag

def check_left(box_coord, box_details, check_box):
    flag = False
    left = box_details[box_coord][2][3]  # add correct values
    print("left point of ", box_coord, ":", left)
    right = box_details[check_box][2][4]  # add correct values
    print("right point of ", check_box, ":", right)
    dist = euclidean(left,right)
    print("Distance between points:",dist)
    #print dist
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
    if (dist < epsilon ):
        flag = True
    print("Boxes to merge or not:", flag)
    return flag

def check_up_left(box_coord, box_details, check_box):
    flag = False
    top_left = box_details[box_coord][2][0]  # add correct values
    print("top_left point of ", box_coord, ":", top_left)
    bottom_right = box_details[check_box][2][7]  # add correct values
    print("bottom_right point of ", check_box, ":", bottom_right)
    dist = euclidean(top_left,bottom_right)
    print("Distance between points:",dist)
    #print dist
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
    if (dist < epsilon ):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag


def euclidean(x, y):
    sumSq = 0.0

    # add up the squared differences
    for i in range(len(x)):
        sumSq += (x[i] - y[i]) ** 2

    # take the square root of the result
    return sumSq ** 0.5
# round off
def re_round(li, _prec=2):
    try:
        return round(li, _prec)
    except TypeError:
        return type(li)(re_round(x, _prec) for x in li)
    


    


supercube_dbscan()
# Out:
# start_box_coord [3.18, 21.92, 21.84, 3.07]
# Graph for visualization of clusters formed:
# box_start_coord [4.46, 22.38, 22.27, 4.35]
# -------------------------------------------------------
# {(4.46, 4.35): [[], [(4.46, 5.63), (5.74, 5.63), (5.74, 4.35)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 0, 0, 0, 0, 0], (4.46, 5.63): [[], [(4.46, 6.91), (3.18, 6.91), (3.18, 5.63), (3.18, 4.35), (4.46, 4.35)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 6.91): [[], [(4.46, 8.19), (3.18, 8.19), (3.18, 6.91), (3.18, 5.63), (4.46, 5.63)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 8.19): [[], [(4.46, 9.47), (3.18, 9.47), (3.18, 8.19), (3.18, 6.91), (4.46, 6.91)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 9.47): [[], [(4.46, 10.75), (3.18, 10.75), (3.18, 9.47), (3.18, 8.19), (4.46, 8.19)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 10.75): [[], [(4.46, 12.03), (3.18, 12.03), (3.18, 10.75), (3.18, 9.47), (4.46, 9.47)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 12.03): [[], [(4.46, 13.31), (3.18, 13.31), (3.18, 12.03), (3.18, 10.75), (4.46, 10.75)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 13.31): [[], [(4.46, 14.59), (3.18, 14.59), (3.18, 13.31), (3.18, 12.03), (4.46, 12.03)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 14.59): [[], [(4.46, 15.87), (3.18, 15.87), (3.18, 14.59), (3.18, 13.31), (4.46, 13.31)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 15.87): [[], [(4.46, 17.15), (3.18, 17.15), (3.18, 15.87), (3.18, 14.59), (4.46, 14.59)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 17.15): [[], [(4.46, 18.43), (3.18, 18.43), (3.18, 17.15), (3.18, 15.87), (4.46, 15.87)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 18.43): [[], [(4.46, 19.71), (3.18, 19.71), (3.18, 18.43), (3.18, 17.15), (4.46, 17.15)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 19.71): [[], [(4.46, 20.99), (3.18, 20.99), (3.18, 19.71), (3.18, 18.43), (4.46, 18.43)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 20.99): [[], [(4.46, 22.27), (3.18, 22.27), (3.18, 20.99), (3.18, 19.71), (4.46, 19.71)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.46, 22.27): [[], [(5.74, 22.27), (5.74, 23.55), (4.46, 23.55)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 0, 0, 0, 0, 0], (5.74, 4.35): [[], [(4.46, 4.35), (7.02, 4.35), (5.74, 5.63), (4.46, 5.63), (7.02, 5.63)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (5.74, 5.63): [[], [(4.46, 6.91), (5.74, 6.91), (7.02, 6.91), (4.46, 5.63), (7.02, 5.63), (4.46, 4.35), (5.74, 4.35), (7.02, 4.35)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 2, 0, 0, 0, 0], (5.74, 6.91): [[], [(4.46, 8.19), (5.74, 8.19), (7.02, 8.19), (4.46, 6.91), (7.02, 6.91), (4.46, 5.63), (5.74, 5.63), (7.02, 5.63)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, - ...
# Current Box: (4.46, 4.35)
# Cluster_id before calling clustering on box  (4.46, 4.35) : 1
# Flag details before checking flag  1 1
# Inside first if
# First level top box (4.46, 5.63)
# top point of  (4.46, 4.35) : (3.95, 4.31)
# bottom point of  (4.46, 5.63) : (3.74, 4.56)
# Distance between points: 0.32649655434629016
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (4.46, 5.63) 1
# Flag details before checking flag  1 1
# Inside first if
# First level top box (4.46, 6.91)
# top point of  (4.46, 5.63) : (4.29, 5.34)
# bottom point of  (4.46, 6.91) : (4.28, 6.15)
# Distance between points: 0.810061726043146
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (4.46, 6.91) 1
# Flag details before checking flag  1 1
# Inside first if
# First level top box (4.46, 8.19)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (5.74, 8.19)
# top_right point of  (4.46, 6.91) : (4.41, 6.6)
# bottom_left point of  (5.74, 8.19) : (5.16, 6.93)
# Distance between points: 0.8193900170248598
# Boxes to merge or not: True
# To merge or not to merge top right level  True
# clustering id for 1st top right box 1
# calling clustering on (5.74, 8.19)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (5.74, 9.47)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (7.02, 9.47)
# checking for right 1st  level box
# 1st level right level =  (7.02, 8.19)
# Calling for Second level for  right
# choosing 2nd level box right (8.3, 8.19)
# Second Level box: (8.3, 8.19)
# right point of  (7.02, 8.19) : (-999, -999)
# left point of  (8.3, 8.19) : (7.5, 8.12)
# Distance between points: 1423.8444242261862
# Boxes to merge or not: False
# To merge or not to merge second level right  False
# checking for down right 1st  level box
# 1st level down right box =  (7.02, 6.91)
# bottom_right point of  (5.74, 8.19) : (5.16, 6.93)
# top_left point of  (7.02, 6.91) : (6.06, 6.68)
# Distance between points: 0.9340770846134697
# Boxes to merge or not: True
# To merge or not to merge  down right level  True
# clustering id for 1st down right box 1
# calling clustering on (7.02, 6.91)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (7.02, 8.19)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (8.3, 8.19)
# top_right point of  (7.02, 6.91) : (6.06, 6.68)
# bottom_left point of  (8.3, 8.19) : (8.21, 7.26)
# Distance between points: 2.2268587741480164
# Boxes to merge or not: False
# To merge or not to merge top right level  False
# checking for right 1st  level box
# 1st level right level =  (8.3, 6.91)
# Calling for Second level for  right
# choosing 2nd level box right (9.58, 6.91)
# checking for down right 1st  level box
# 1st level down right box =  (8.3, 5.63)
# checking for down 1st  level box
# 1st level down level =  (7.02, 5.63)
# bottom point of  (7.02, 6.91) : (6.59, 5.74)
# top point of  (7.02, 5.63) : (6.62, 5.4)
# Distance between points: 0.3413209633175201
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 1
# calling clustering on (7.02, 5.63)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (7.02, 6.91)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (8.3, 6.91)
# checking for right 1st  level box
# 1st level right level =  (8.3, 5.63)
# Calling for Second level for  right
# choosing 2nd level box right (9.58, 5.63)
# checking for down right 1st  level box
# 1st level down right box =  (8.3, 4.35)
# checking for down 1st  level box
# 1st level down level =  (7.02, 4.35)
# Calling for Second level for down
# choosing 2nd level box down (7.02, 3.07)
# checking for left down 1st  level box
# 1st level down left box =  (5.74, 4.35)
# bottom_left point of  (7.02, 5.63) : (5.77, 4.88)
# top_right point of  (5.74, 4.35) : (5.58, 4.0)
# Distance between points: 0.900277734924062
# Boxes to merge or not: True
# To merge or not to merge left down level   True
# clustering id for 1st down left box 1
# calling clustering on (5.74, 4.35)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (5.74, 5.63)
# top point of  (5.74, 4.35) : (4.78, 4.3)
# bottom point of  (5.74, 5.63) : (5.08, 4.53)
# Distance between points: 0.3780211634287161
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (5.74, 5.63) 1
# Flag details before checking flag  1 1
# Inside first if
# First level top box (5.74, 6.91)
# top point of  (5.74, 5.63) : (5.12, 5.16)
# bottom point of  (5.74, 6.91) : (5.08, 5.7)
# Distance between points: 0.5414794548272354
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (5.74, 6.91) 1
# Flag details before checking flag  1 1
# Inside first if
# First level top box (5.74, 8.19)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (7.02, 8.19)
# checking for right 1st  level box
# 1st level right level =  (7.02, 6.91)
# Calling for Second level for  right
# choosing 2nd level box right (8.3, 6.91)
# checking for down right 1st  level box
# 1st level down right box =  (7.02, 5.63)
# checking for down 1st  level box
# 1st level down level =  (5.74, 5.63)
# Calling for Second level for down
# choosing 2nd level box down (5.74, 4.35)
# checking for left down 1st  level box
# 1st level down left box =  (4.46, 5.63)
# checking for left 1st  level box
# 1st level left box =  (4.46, 6.91)
# Calling for Second level for left
# choosing 2nd level box up left  (3.18, 6.91)
# checking for up left 1st  level box
# 1st level up left box =  (4.46, 8.19)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (7.02, 6.91)
# checking for right 1st  level box
# 1st level right level =  (7.02, 5.63)
# Calling for Second level for  right
# choosing 2nd level box right (8.3, 5.63)
# checking for down right 1st  level box
# 1st level down right box =  (7.02, 4.35)
# checking for down 1st  level box
# 1st level down level =  (5.74, 4.35)
# Calling for Second level for down
# choosing 2nd level box down (5.74, 3.07)
# checking for left down 1st  level box
# 1st level down left box =  (4.46, 4.35)
# checking for left 1st  level box
# 1st level left box =  (4.46, 5.63)
# Calling for Second level for left
# choosing 2nd level box up left  (3.18, 5.63)
# checking for up left 1st  level box
# 1st level up left box =  (4.46, 6.91)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (7.02, 5.63)
# checking for right 1st  level box
# 1st level right level =  (7.02, 4.35)
# Calling for Second level for  right
# choosing 2nd level box right (8.3, 4.35)
# checking for down right 1st  level box
# 1st level down right box =  (7.02, 3.07)
# checking for down 1st  level box
# 1st level down level =  (5.74, 3.07)
# checking for left down 1st  level box
# 1st level down left box =  (4.46, 3.07)
# checking for left 1st  level box
# 1st level left box =  (4.46, 4.35)
# Calling for Second level for left
# choosing 2nd level box up left  (3.18, 4.35)
# checking for up left 1st  level box
# 1st level up left box =  (4.46, 5.63)
# checking for left 1st  level box
# 1st level left box =  (5.74, 5.63)
# Calling for Second level for left
# choosing 2nd level box up left  (4.46, 5.63)
# checking for up left 1st  level box
# 1st level up left box =  (5.74, 6.91)
# Calling for Second level for down
# choosing 2nd level box down (7.02, 4.35)
# checking for left down 1st  level box
# 1st level down left box =  (5.74, 5.63)
# checking for left 1st  level box
# 1st level left box =  (5.74, 6.91)
# Calling for Second level for left
# choosing 2nd level box up left  (4.46, 6.91)
# checking for up left 1st  level box
# 1st level up left box =  (5.74, 8.19)
# checking for down 1st  level box
# 1st level down level =  (5.74, 6.91)
# Calling for Second level for down
# choosing 2nd level box down (5.74, 5.63)
# checking for left down 1st  level box
# 1st level down left box =  (4.46, 6.91)
# checking for left 1st  level box
# 1st level left box =  (4.46, 8.19)
# Calling for Second level for left
# choosing 2nd level box up left  (3.18, 8.19)
# checking for up left 1st  level box
# 1st level up left box =  (4.46, 9.47)
# checking for right 1st  level box
# 1st level right level =  (5.74, 6.91)
# Calling for Second level for  right
# choosing 2nd level box right (7.02, 6.91)
# checking for down right 1st  level box
# 1st level down right box =  (5.74, 5.63)
# checking for down 1st  level box
# 1st level down level =  (4.46, 5.63)
# Calling for Second level for down
# choosing 2nd level box down (4.46, 4.35)
# checking for left down 1st  level box
# 1st level down left box =  (3.18, 5.63)
# checking for left 1st  level box
# 1st level left box =  (3.18, 6.91)
# checking for up left 1st  level box
# 1st level up left box =  (3.18, 8.19)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (5.74, 6.91)
# checking for right 1st  level box
# 1st level right level =  (5.74, 5.63)
# Calling for Second level for  right
# choosing 2nd level box right (7.02, 5.63)
# checking for down right 1st  level box
# 1st level down right box =  (5.74, 4.35)
# checking for down 1st  level box
# 1st level down level =  (4.46, 4.35)
# Calling for Second level for down
# choosing 2nd level box down (4.46, 3.07)
# checking for left down 1st  level box
# 1st level down left box =  (3.18, 4.35)
# checking for left 1st  level box
# 1st level left box =  (3.18, 5.63)
# checking for up left 1st  level box
# 1st level up left box =  (3.18, 6.91)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (5.74, 5.63)
# checking for right 1st  level box
# 1st level right level =  (5.74, 4.35)
# Calling for Second level for  right
# choosing 2nd level box right (7.02, 4.35)
# checking for down right 1st  level box
# 1st level down right box =  (5.74, 3.07)
# checking for down 1st  level box
# 1st level down level =  (4.46, 3.07)
# checking for left down 1st  level box
# 1st level down left box =  (3.18, 3.07)
# checking for left 1st  level box
# 1st level left box =  (3.18, 4.35)
# checking for up left 1st  level box
# 1st level up left box =  (3.18, 5.63)
# Current Box: (4.46, 5.63)
# Current Box: (4.46, 6.91)
# Current Box: (4.46, 8.19)
# Current Box: (4.46, 9.47)
# Current Box: (4.46, 10.75)
# Current Box: (4.46, 12.03)
# Current Box: (4.46, 13.31)
# Current Box: (4.46, 14.59)
# Current Box: (4.46, 15.87)
# Current Box: (4.46, 17.15)
# Current Box: (4.46, 18.43)
# Current Box: (4.46, 19.71)
# Current Box: (4.46, 20.99)
# Current Box: (4.46, 22.27)
# Current Box: (5.74, 4.35)
# Current Box: (5.74, 5.63)
# Current Box: (5.74, 6.91)
# Current Box: (5.74, 8.19)
# Current Box: (5.74, 9.47)
# Current Box: (5.74, 10.75)
# Current Box: (5.74, 12.03)
# Current Box: (5.74, 13.31)
# Current Box: (5.74, 14.59)
# Current Box: (5.74, 15.87)
# Current Box: (5.74, 17.15)
# Current Box: (5.74, 18.43)
# Current Box: (5.74, 19.71)
# Current Box: (5.74, 20.99)
# Current Box: (5.74, 22.27)
# Current Box: (7.02, 4.35)
# Current Box: (7.02, 5.63)
# Current Box: (7.02, 6.91)
# Current Box: (7.02, 8.19)
# Current Box: (7.02, 9.47)
# Current Box: (7.02, 10.75)
# Current Box: (7.02, 12.03)
# Current Box: (7.02, 13.31)
# Current Box: (7.02, 14.59)
# Current Box: (7.02, 15.87)
# Current Box: (7.02, 17.15)
# Current Box: (7.02, 18.43)
# Current Box: (7.02, 19.71)
# Current Box: (7.02, 20.99)
# Current Box: (7.02, 22.27)
# Current Box: (8.3, 4.35)
# Current Box: (8.3, 5.63)
# Current Box: (8.3, 6.91)
# Current Box: (8.3, 8.19)
# Cluster_id before calling clustering on box  (8.3, 8.19) : 2
# Flag details before checking flag  1 1
# Inside first if
# First level top box (8.3, 9.47)
# top point of  (8.3, 8.19) : (7.5, 8.12)
# bottom point of  (8.3, 9.47) : (7.73, 8.33)
# Distance between points: 0.31144823004794964
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (8.3, 9.47) 2
# Flag details before checking flag  1 1
# Inside first if
# First level top box (8.3, 10.75)
# top point of  (8.3, 9.47) : (8.19, 9.37)
# bottom point of  (8.3, 10.75) : (7.7, 9.57)
# Distance between points: 0.5292447448959695
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (8.3, 10.75) 2
# Flag details before checking flag  1 1
# Inside first if
# First level top box (8.3, 12.03)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (9.58, 12.03)
# checking for right 1st  level box
# 1st level right level =  (9.58, 10.75)
# right point of  (8.3, 10.75) : (7.76, 10.52)
# left point of  (9.58, 10.75) : (8.62, 9.68)
# Distance between points: 1.202164714171897
# Boxes to merge or not: True
# To merge or not to merge right level  True
# clustering id for 1st right box 2
# calling clustering on (9.58, 10.75)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (9.58, 12.03)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (10.86, 12.03)
# checking for right 1st  level box
# 1st level right level =  (10.86, 10.75)
# right point of  (9.58, 10.75) : (9.28, 10.19)
# left point of  (10.86, 10.75) : (9.62, 9.97)
# Distance between points: 0.404969134626331
# Boxes to merge or not: True
# To merge or not to merge right level  True
# clustering id for 1st right box 2
# calling clustering on (10.86, 10.75)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (10.86, 12.03)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (12.14, 12.03)
# checking for right 1st  level box
# 1st level right level =  (12.14, 10.75)
# Calling for Second level for  right
# choosing 2nd level box right (13.42, 10.75)
# checking for down right 1st  level box
# 1st level down right box =  (12.14, 9.47)
# checking for down 1st  level box
# 1st level down level =  (10.86, 9.47)
# bottom point of  (10.86, 10.75) : (10.51, 10.03)
# top point of  (10.86, 9.47) : (10.5, 8.77)
# Distance between points: 1.2600396819148194
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 2
# calling clustering on (10.86, 9.47)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (10.86, 10.75)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (12.14, 10.75)
# checking for right 1st  level box
# 1st level right level =  (12.14, 9.47)
# Calling for Second level for  right
# choosing 2nd level box right (13.42, 9.47)
# checking for down right 1st  level box
# 1st level down right box =  (12.14, 8.19)
# checking for down 1st  level box
# 1st level down level =  (10.86, 8.19)
# bottom point of  (10.86, 9.47) : (10.3, 8.27)
# top point of  (10.86, 8.19) : (10.32, 8.07)
# Distance between points: 0.20099751242241706
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 2
# calling clustering on (10.86, 8.19)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (10.86, 9.47)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (12.14, 9.47)
# checking for right 1st  level box
# 1st level right level =  (12.14, 8.19)
# Calling for Second level for  right
# choosing 2nd level box right (13.42, 8.19)
# checking for down right 1st  level box
# 1st level down right box =  (12.14, 6.91)
# checking for down 1st  level box
# 1st level down level =  (10.86, 6.91)
# Calling for Second level for down
# choosing 2nd level box down (10.86, 5.63)
# checking for left down 1st  level box
# 1st level down left box =  (9.58, 6.91)
# checking for left 1st  level box
# 1st level left box =  (9.58, 8.19)
# left point of  (10.86, 8.19) : (9.87, 7.37)
# right point of  (9.58, 8.19) : (8.93, 8.15)
# Distance between points: 1.2214745187681975
# Boxes to merge or not: True
# To merge or not to merge left level   True
# clustering id for 1st left box 2
# calling clustering on (9.58, 8.19)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (9.58, 9.47)
# top point of  (9.58, 8.19) : (8.93, 8.15)
# bottom point of  (9.58, 9.47) : (9.1, 8.25)
# Distance between points: 0.19723082923315996
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (9.58, 9.47) 2
# Flag details before checking flag  1 1
# Inside first if
# First level top box (9.58, 10.75)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (10.86, 10.75)
# checking for right 1st  level box
# 1st level right level =  (10.86, 9.47)
# Calling for Second level for  right
# choosing 2nd level box right (12.14, 9.47)
# checking for down right 1st  level box
# 1st level down right box =  (10.86, 8.19)
# checking for down 1st  level box
# 1st level down level =  (9.58, 8.19)
# Calling for Second level for down
# choosing 2nd level box down (9.58, 6.91)
# checking for left down 1st  level box
# 1st level down left box =  (8.3, 8.19)
# checking for left 1st  level box
# 1st level left box =  (8.3, 9.47)
# Calling for Second level for left
# choosing 2nd level box up left  (7.02, 9.47)
# checking for up left 1st  level box
# 1st level up left box =  (8.3, 10.75)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (10.86, 9.47)
# checking for right 1st  level box
# 1st level right level =  (10.86, 8.19)
# Calling for Second level for  right
# choosing 2nd level box right (12.14, 8.19)
# checking for down right 1st  level box
# 1st level down right box =  (10.86, 6.91)
# checking for down 1st  level box
# 1st level down level =  (9.58, 6.91)
# Calling for Second level for down
# choosing 2nd level box down (9.58, 5.63)
# checking for left down 1st  level box
# 1st level down left box =  (8.3, 6.91)
# checking for left 1st  level box
# 1st level left box =  (8.3, 8.19)
# Calling for Second level for left
# choosing 2nd level box up left  (7.02, 8.19)
# checking for up left 1st  level box
# 1st level up left box =  (8.3, 9.47)
# Calling for Second level for left
# choosing 2nd level box up left  (8.3, 8.19)
# checking for up left 1st  level box
# 1st level up left box =  (9.58, 9.47)
# Calling for Second level for down
# choosing 2nd level box down (10.86, 6.91)
# checking for left down 1st  level box
# 1st level down left box =  (9.58, 8.19)
# checking for left 1st  level box
# 1st level left box =  (9.58, 9.47)
# Calling for Second level for left
# choosing 2nd level box up left  (8.3, 9.47)
# checking for up left 1st  level box
# 1st level up left box =  (9.58, 10.75)
# Calling for Second level for down
# choosing 2nd level box down (10.86, 8.19)
# checking for left down 1st  level box
# 1st level down left box =  (9.58, 9.47)
# checking for left 1st  level box
# 1st level left box =  (9.58, 10.75)
# Calling for Second level for left
# choosing 2nd level box up left  (8.3, 10.75)
# checking for up left 1st  level box
# 1st level up left box =  (9.58, 12.03)
# Calling for Second level for  right
# choosing 2nd level box right (12.14, 10.75)
# checking for down right 1st  level box
# 1st level down right box =  (10.86, 9.47)
# checking for down 1st  level box
# 1st level down level =  (9.58, 9.47)
# Calling for Second level for down
# choosing 2nd level box down (9.58, 8.19)
# checking for left down 1st  level box
# 1st level down left box =  (8.3, 9.47)
# checking for left 1st  level box
# 1st level left box =  (8.3, 10.75)
# Calling for Second level for left
# choosing 2nd level box up left  (7.02, 10.75)
# checking for up left 1st  level box
# 1st level up left box =  (8.3, 12.03)
# Calling for Second level for  right
# choosing 2nd level box right (10.86, 10.75)
# checking for down right 1st  level box
# 1st level down right box =  (9.58, 9.47)
# checking for down 1st  level box
# 1st level down level =  (8.3, 9.47)
# Calling for Second level for down
# choosing 2nd level box down (8.3, 8.19)
# checking for left down 1st  level box
# 1st level down left box =  (7.02, 9.47)
# checking for left 1st  level box
# 1st level left box =  (7.02, 10.75)
# Calling for Second level for left
# choosing 2nd level box up left  (5.74, 10.75)
# checking for up left 1st  level box
# 1st level up left box =  (7.02, 12.03)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (9.58, 10.75)
# checking for right 1st  level box
# 1st level right level =  (9.58, 9.47)
# Calling for Second level for  right
# choosing 2nd level box right (10.86, 9.47)
# checking for down right 1st  level box
# 1st level down right box =  (9.58, 8.19)
# checking for down 1st  level box
# 1st level down level =  (8.3, 8.19)
# Calling for Second level for down
# choosing 2nd level box down (8.3, 6.91)
# checking for left down 1st  level box
# 1st level down left box =  (7.02, 8.19)
# checking for left 1st  level box
# 1st level left box =  (7.02, 9.47)
# Calling for Second level for left
# choosing 2nd level box up left  (5.74, 9.47)
# checking for up left 1st  level box
# 1st level up left box =  (7.02, 10.75)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (9.58, 9.47)
# checking for right 1st  level box
# 1st level right level =  (9.58, 8.19)
# Calling for Second level for  right
# choosing 2nd level box right (10.86, 8.19)
# checking for down right 1st  level box
# 1st level down right box =  (9.58, 6.91)
# checking for down 1st  level box
# 1st level down level =  (8.3, 6.91)
# Calling for Second level for down
# choosing 2nd level box down (8.3, 5.63)
# checking for left down 1st  level box
# 1st level down left box =  (7.02, 6.91)
# checking for left 1st  level box
# 1st level left box =  (7.02, 8.19)
# Calling for Second level for left
# choosing 2nd level box up left  (5.74, 8.19)
# checking for up left 1st  level box
# 1st level up left box =  (7.02, 9.47)
# Current Box: (8.3, 9.47)
# Current Box: (8.3, 10.75)
# Current Box: (8.3, 12.03)
# Current Box: (8.3, 13.31)
# Current Box: (8.3, 14.59)
# Current Box: (8.3, 15.87)
# Current Box: (8.3, 17.15)
# Current Box: (8.3, 18.43)
# Current Box: (8.3, 19.71)
# Current Box: (8.3, 20.99)
# Current Box: (8.3, 22.27)
# Current Box: (9.58, 4.35)
# Current Box: (9.58, 5.63)
# Current Box: (9.58, 6.91)
# Current Box: (9.58, 8.19)
# Current Box: (9.58, 9.47)
# Current Box: (9.58, 10.75)
# Current Box: (9.58, 12.03)
# Current Box: (9.58, 13.31)
# Current Box: (9.58, 14.59)
# Current Box: (9.58, 15.87)
# Current Box: (9.58, 17.15)
# Current Box: (9.58, 18.43)
# Current Box: (9.58, 19.71)
# Current Box: (9.58, 20.99)
# Current Box: (9.58, 22.27)
# Current Box: (10.86, 4.35)
# Current Box: (10.86, 5.63)
# Current Box: (10.86, 6.91)
# Current Box: (10.86, 8.19)
# Current Box: (10.86, 9.47)
# Current Box: (10.86, 10.75)
# Current Box: (10.86, 12.03)
# Current Box: (10.86, 13.31)
# Current Box: (10.86, 14.59)
# Current Box: (10.86, 15.87)
# Current Box: (10.86, 17.15)
# Current Box: (10.86, 18.43)
# Current Box: (10.86, 19.71)
# Current Box: (10.86, 20.99)
# Current Box: (10.86, 22.27)
# Current Box: (12.14, 4.35)
# Current Box: (12.14, 5.63)
# Current Box: (12.14, 6.91)
# Current Box: (12.14, 8.19)
# Current Box: (12.14, 9.47)
# Current Box: (12.14, 10.75)
# Current Box: (12.14, 12.03)
# Current Box: (12.14, 13.31)
# Current Box: (12.14, 14.59)
# Current Box: (12.14, 15.87)
# Current Box: (12.14, 17.15)
# Current Box: (12.14, 18.43)
# Current Box: (12.14, 19.71)
# Current Box: (12.14, 20.99)
# Current Box: (12.14, 22.27)
# Current Box: (13.42, 4.35)
# Current Box: (13.42, 5.63)
# Current Box: (13.42, 6.91)
# Current Box: (13.42, 8.19)
# Current Box: (13.42, 9.47)
# Current Box: (13.42, 10.75)
# Current Box: (13.42, 12.03)
# Current Box: (13.42, 13.31)
# Current Box: (13.42, 14.59)
# Current Box: (13.42, 15.87)
# Current Box: (13.42, 17.15)
# Current Box: (13.42, 18.43)
# Current Box: (13.42, 19.71)
# Current Box: (13.42, 20.99)
# Current Box: (13.42, 22.27)
# Current Box: (14.7, 4.35)
# Current Box: (14.7, 5.63)
# Current Box: (14.7, 6.91)
# Current Box: (14.7, 8.19)
# Current Box: (14.7, 9.47)
# Current Box: (14.7, 10.75)
# Current Box: (14.7, 12.03)
# Current Box: (14.7, 13.31)
# Current Box: (14.7, 14.59)
# Current Box: (14.7, 15.87)
# Cluster_id before calling clustering on box  (14.7, 15.87) : 3
# Flag details before checking flag  1 1
# Inside first if
# First level top box (14.7, 17.15)
# top point of  (14.7, 15.87) : (14.54, 15.71)
# bottom point of  (14.7, 17.15) : (14.27, 15.99)
# Distance between points: 0.3889730067755337
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (14.7, 17.15) 3
# Flag details before checking flag  1 1
# Inside first if
# First level top box (14.7, 18.43)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (15.98, 18.43)
# top_right point of  (14.7, 17.15) : (14.61, 16.84)
# bottom_left point of  (15.98, 18.43) : (14.82, 17.4)
# Distance between points: 0.5980802621722263
# Boxes to merge or not: True
# To merge or not to merge top right level  True
# clustering id for 1st top right box 3
# calling clustering on (15.98, 18.43)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (15.98, 19.71)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (17.26, 19.71)
# checking for right 1st  level box
# 1st level right level =  (17.26, 18.43)
# right point of  (15.98, 18.43) : (15.79, 17.88)
# left point of  (17.26, 18.43) : (16.1, 17.69)
# Distance between points: 0.3635931792539576
# Boxes to merge or not: True
# To merge or not to merge right level  True
# clustering id for 1st right box 3
# calling clustering on (17.26, 18.43)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (17.26, 19.71)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (18.54, 19.71)
# checking for right 1st  level box
# 1st level right level =  (18.54, 18.43)
# Calling for Second level for  right
# choosing 2nd level box right (19.82, 18.43)
# Second Level box: (19.82, 18.43)
# right point of  (18.54, 18.43) : (-999, -999)
# left point of  (19.82, 18.43) : (19.13, 18.25)
# Distance between points: 1439.2311348077485
# Boxes to merge or not: False
# To merge or not to merge second level right  False
# checking for down right 1st  level box
# 1st level down right box =  (18.54, 17.15)
# bottom_right point of  (17.26, 18.43) : (16.5, 17.8)
# top_left point of  (18.54, 17.15) : (17.51, 16.42)
# Distance between points: 1.71011695506477
# Boxes to merge or not: True
# To merge or not to merge  down right level  True
# clustering id for 1st down right box 3
# calling clustering on (18.54, 17.15)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (18.54, 18.43)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (19.82, 18.43)
# top_right point of  (18.54, 17.15) : (17.94, 16.28)
# bottom_left point of  (19.82, 18.43) : (19.13, 18.25)
# Distance between points: 2.3015212360523614
# Boxes to merge or not: False
# To merge or not to merge top right level  False
# checking for right 1st  level box
# 1st level right level =  (19.82, 17.15)
# Calling for Second level for  right
# choosing 2nd level box right (21.1, 17.15)
# checking for down right 1st  level box
# 1st level down right box =  (19.82, 15.87)
# checking for down 1st  level box
# 1st level down level =  (18.54, 15.87)
# bottom point of  (18.54, 17.15) : (17.94, 16.28)
# top point of  (18.54, 15.87) : (17.64, 15.59)
# Distance between points: 0.7523961722390686
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 3
# calling clustering on (18.54, 15.87)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (18.54, 17.15)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (19.82, 17.15)
# checking for right 1st  level box
# 1st level right level =  (19.82, 15.87)
# Calling for Second level for  right
# choosing 2nd level box right (21.1, 15.87)
# checking for down right 1st  level box
# 1st level down right box =  (19.82, 14.59)
# checking for down 1st  level box
# 1st level down level =  (18.54, 14.59)
# Calling for Second level for down
# choosing 2nd level box down (18.54, 13.31)
# checking for left down 1st  level box
# 1st level down left box =  (17.26, 14.59)
# bottom_left point of  (18.54, 15.87) : (17.26, 14.75)
# top_right point of  (17.26, 14.59) : (16.29, 14.13)
# Distance between points: 1.1512167476196669
# Boxes to merge or not: True
# To merge or not to merge left down level   True
# clustering id for 1st down left box 3
# calling clustering on (17.26, 14.59)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (17.26, 15.87)
# top point of  (17.26, 14.59) : (16.29, 14.13)
# bottom point of  (17.26, 15.87) : (16.4, 15.09)
# Distance between points: 0.9662815324738427
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (17.26, 15.87) 3
# Flag details before checking flag  1 1
# Inside first if
# First level top box (17.26, 17.15)
# top point of  (17.26, 15.87) : (16.63, 15.6)
# bottom point of  (17.26, 17.15) : (17.03, 16.17)
# Distance between points: 0.6963476143421503
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (17.26, 17.15) 3
# Flag details before checking flag  1 1
# Inside first if
# First level top box (17.26, 18.43)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (18.54, 18.43)
# checking for right 1st  level box
# 1st level right level =  (18.54, 17.15)
# Calling for Second level for  right
# choosing 2nd level box right (19.82, 17.15)
# checking for down right 1st  level box
# 1st level down right box =  (18.54, 15.87)
# checking for down 1st  level box
# 1st level down level =  (17.26, 15.87)
# Calling for Second level for down
# choosing 2nd level box down (17.26, 14.59)
# checking for left down 1st  level box
# 1st level down left box =  (15.98, 15.87)
# bottom_left point of  (17.26, 17.15) : (16.15, 16.29)
# top_right point of  (15.98, 15.87) : (15.94, 15.01)
# Distance between points: 1.297112177107284
# Boxes to merge or not: True
# To merge or not to merge left down level   True
# clustering id for 1st down left box 3
# calling clustering on (15.98, 15.87)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (15.98, 17.15)
# top point of  (15.98, 15.87) : (14.77, 15.24)
# bottom point of  (15.98, 17.15) : (15.37, 15.95)
# Distance between points: 0.9295697929687681
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (15.98, 17.15) 3
# Flag details before checking flag  1 1
# Inside first if
# First level top box (15.98, 18.43)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (17.26, 18.43)
# checking for right 1st  level box
# 1st level right level =  (17.26, 17.15)
# Calling for Second level for  right
# choosing 2nd level box right (18.54, 17.15)
# checking for down right 1st  level box
# 1st level down right box =  (17.26, 15.87)
# checking for down 1st  level box
# 1st level down level =  (15.98, 15.87)
# Calling for Second level for down
# choosing 2nd level box down (15.98, 14.59)
# bottom point of  (15.98, 15.87) : (15.62, 14.81)
# top point of  (15.98, 14.59) : (15.33, 14.52)
# Distance between points: 0.4101219330881976
# Boxes to merge or not: True
# New cluster_id for down box jplus1 (15.98, 14.59) 3
# Calling clustering on down box second level
# Flag details before checking flag  1 1
# Inside first if
# First level top box (15.98, 15.87)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (17.26, 15.87)
# checking for right 1st  level box
# 1st level right level =  (17.26, 14.59)
# Calling for Second level for  right
# choosing 2nd level box right (18.54, 14.59)
# checking for down right 1st  level box
# 1st level down right box =  (17.26, 13.31)
# checking for down 1st  level box
# 1st level down level =  (15.98, 13.31)
# Calling for Second level for down
# choosing 2nd level box down (15.98, 12.03)
# checking for left down 1st  level box
# 1st level down left box =  (14.7, 13.31)
# checking for left 1st  level box
# 1st level left box =  (14.7, 14.59)
# Calling for Second level for left
# choosing 2nd level box up left  (13.42, 14.59)
# checking for up left 1st  level box
# 1st level up left box =  (14.7, 15.87)
# checking for left down 1st  level box
# 1st level down left box =  (14.7, 15.87)
# checking for left 1st  level box
# 1st level left box =  (14.7, 17.15)
# Calling for Second level for left
# choosing 2nd level box up left  (13.42, 17.15)
# checking for up left 1st  level box
# 1st level up left box =  (14.7, 18.43)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (17.26, 17.15)
# checking for right 1st  level box
# 1st level right level =  (17.26, 15.87)
# Calling for Second level for  right
# choosing 2nd level box right (18.54, 15.87)
# checking for down right 1st  level box
# 1st level down right box =  (17.26, 14.59)
# checking for down 1st  level box
# 1st level down level =  (15.98, 14.59)
# Calling for Second level for down
# choosing 2nd level box down (15.98, 13.31)
# checking for left down 1st  level box
# 1st level down left box =  (14.7, 14.59)
# checking for left 1st  level box
# 1st level left box =  (14.7, 15.87)
# Calling for Second level for left
# choosing 2nd level box up left  (13.42, 15.87)
# checking for up left 1st  level box
# 1st level up left box =  (14.7, 17.15)
# checking for left 1st  level box
# 1st level left box =  (15.98, 17.15)
# Calling for Second level for left
# choosing 2nd level box up left  (14.7, 17.15)
# checking for up left 1st  level box
# 1st level up left box =  (15.98, 18.43)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (18.54, 17.15)
# checking for right 1st  level box
# 1st level right level =  (18.54, 15.87)
# Calling for Second level for  right
# choosing 2nd level box right (19.82, 15.87)
# checking for down right 1st  level box
# 1st level down right box =  (18.54, 14.59)
# checking for down 1st  level box
# 1st level down level =  (17.26, 14.59)
# Calling for Second level for down
# choosing 2nd level box down (17.26, 13.31)
# checking for left down 1st  level box
# 1st level down left box =  (15.98, 14.59)
# checking for left 1st  level box
# 1st level left box =  (15.98, 15.87)
# Calling for Second level for left
# choosing 2nd level box up left  (14.7, 15.87)
# checking for up left 1st  level box
# 1st level up left box =  (15.98, 17.15)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (18.54, 15.87)
# checking for right 1st  level box
# 1st level right level =  (18.54, 14.59)
# Calling for Second level for  right
# choosing 2nd level box right (19.82, 14.59)
# checking for down right 1st  level box
# 1st level down right box =  (18.54, 13.31)
# checking for down 1st  level box
# 1st level down level =  (17.26, 13.31)
# Calling for Second level for down
# choosing 2nd level box down (17.26, 12.03)
# checking for left down 1st  level box
# 1st level down left box =  (15.98, 13.31)
# checking for left 1st  level box
# 1st level left box =  (15.98, 14.59)
# Calling for Second level for left
# choosing 2nd level box up left  (14.7, 14.59)
# checking for up left 1st  level box
# 1st level up left box =  (15.98, 15.87)
# checking for left 1st  level box
# 1st level left box =  (17.26, 15.87)
# Calling for Second level for left
# choosing 2nd level box up left  (15.98, 15.87)
# checking for up left 1st  level box
# 1st level up left box =  (17.26, 17.15)
# Calling for Second level for down
# choosing 2nd level box down (18.54, 14.59)
# checking for left down 1st  level box
# 1st level down left box =  (17.26, 15.87)
# checking for left 1st  level box
# 1st level left box =  (17.26, 17.15)
# Calling for Second level for left
# choosing 2nd level box up left  (15.98, 17.15)
# checking for up left 1st  level box
# 1st level up left box =  (17.26, 18.43)
# checking for down 1st  level box
# 1st level down level =  (17.26, 17.15)
# Calling for Second level for down
# choosing 2nd level box down (17.26, 15.87)
# checking for left down 1st  level box
# 1st level down left box =  (15.98, 17.15)
# checking for left 1st  level box
# 1st level left box =  (15.98, 18.43)
# Calling for Second level for left
# choosing 2nd level box up left  (14.7, 18.43)
# checking for up left 1st  level box
# 1st level up left box =  (15.98, 19.71)
# Calling for Second level for  right
# choosing 2nd level box right (18.54, 18.43)
# checking for down right 1st  level box
# 1st level down right box =  (17.26, 17.15)
# checking for down 1st  level box
# 1st level down level =  (15.98, 17.15)
# Calling for Second level for down
# choosing 2nd level box down (15.98, 15.87)
# checking for left down 1st  level box
# 1st level down left box =  (14.7, 17.15)
# checking for left 1st  level box
# 1st level left box =  (14.7, 18.43)
# Calling for Second level for left
# choosing 2nd level box up left  (13.42, 18.43)
# checking for up left 1st  level box
# 1st level up left box =  (14.7, 19.71)
# checking for right 1st  level box
# 1st level right level =  (15.98, 17.15)
# Calling for Second level for  right
# choosing 2nd level box right (17.26, 17.15)
# checking for down right 1st  level box
# 1st level down right box =  (15.98, 15.87)
# checking for down 1st  level box
# 1st level down level =  (14.7, 15.87)
# Calling for Second level for down
# choosing 2nd level box down (14.7, 14.59)
# checking for left down 1st  level box
# 1st level down left box =  (13.42, 15.87)
# checking for left 1st  level box
# 1st level left box =  (13.42, 17.15)
# Calling for Second level for left
# choosing 2nd level box up left  (12.14, 17.15)
# checking for up left 1st  level box
# 1st level up left box =  (13.42, 18.43)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (15.98, 17.15)
# checking for right 1st  level box
# 1st level right level =  (15.98, 15.87)
# Calling for Second level for  right
# choosing 2nd level box right (17.26, 15.87)
# checking for down right 1st  level box
# 1st level down right box =  (15.98, 14.59)
# checking for down 1st  level box
# 1st level down level =  (14.7, 14.59)
# Calling for Second level for down
# choosing 2nd level box down (14.7, 13.31)
# checking for left down 1st  level box
# 1st level down left box =  (13.42, 14.59)
# checking for left 1st  level box
# 1st level left box =  (13.42, 15.87)
# Calling for Second level for left
# choosing 2nd level box up left  (12.14, 15.87)
# checking for up left 1st  level box
# 1st level up left box =  (13.42, 17.15)
# Current Box: (14.7, 17.15)
# Current Box: (14.7, 18.43)
# Current Box: (14.7, 19.71)
# Current Box: (14.7, 20.99)
# Current Box: (14.7, 22.27)
# Current Box: (15.98, 4.35)
# Current Box: (15.98, 5.63)
# Current Box: (15.98, 6.91)
# Current Box: (15.98, 8.19)
# Current Box: (15.98, 9.47)
# Current Box: (15.98, 10.75)
# Current Box: (15.98, 12.03)
# Current Box: (15.98, 13.31)
# Current Box: (15.98, 14.59)
# Current Box: (15.98, 15.87)
# Current Box: (15.98, 17.15)
# Current Box: (15.98, 18.43)
# Current Box: (15.98, 19.71)
# Current Box: (15.98, 20.99)
# Current Box: (15.98, 22.27)
# Current Box: (17.26, 4.35)
# Current Box: (17.26, 5.63)
# Current Box: (17.26, 6.91)
# Current Box: (17.26, 8.19)
# Current Box: (17.26, 9.47)
# Current Box: (17.26, 10.75)
# Current Box: (17.26, 12.03)
# Current Box: (17.26, 13.31)
# Current Box: (17.26, 14.59)
# Current Box: (17.26, 15.87)
# Current Box: (17.26, 17.15)
# Current Box: (17.26, 18.43)
# Current Box: (17.26, 19.71)
# Current Box: (17.26, 20.99)
# Current Box: (17.26, 22.27)
# Current Box: (18.54, 4.35)
# Current Box: (18.54, 5.63)
# Current Box: (18.54, 6.91)
# Current Box: (18.54, 8.19)
# Current Box: (18.54, 9.47)
# Current Box: (18.54, 10.75)
# Current Box: (18.54, 12.03)
# Current Box: (18.54, 13.31)
# Current Box: (18.54, 14.59)
# Current Box: (18.54, 15.87)
# Current Box: (18.54, 17.15)
# Current Box: (18.54, 18.43)
# Current Box: (18.54, 19.71)
# Current Box: (18.54, 20.99)
# Cluster_id before calling clustering on box  (18.54, 20.99) : 4
# Flag details before checking flag  1 1
# Inside first if
# First level top box (18.54, 22.27)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (19.82, 22.27)
# top_right point of  (18.54, 20.99) : (18.4, 19.91)
# bottom_left point of  (19.82, 22.27) : (19.14, 21.21)
# Distance between points: 1.495860956105214
# Boxes to merge or not: True
# To merge or not to merge top right level  True
# clustering id for 1st top right box 4
# calling clustering on (19.82, 22.27)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (19.82, 23.55)
# checking for top right 1st  level box
# 1st level top right level =  (21.1, 23.55)
# checking for right 1st  level box
# 1st level right level =  (21.1, 22.27)
# right point of  (19.82, 22.27) : (19.37, 21.16)
# left point of  (21.1, 22.27) : (20.13, 21.84)
# Distance between points: 1.0198039027185553
# Boxes to merge or not: True
# To merge or not to merge right level  True
# clustering id for 1st right box 4
# calling clustering on (21.1, 22.27)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (21.1, 23.55)
# checking for top right 1st  level box
# 1st level top right level =  (22.38, 23.55)
# checking for right 1st  level box
# 1st level right level =  (22.38, 22.27)
# Calling for Second level for  right
# choosing 2nd level box right (23.66, 22.27)
# checking for down right 1st  level box
# 1st level down right box =  (22.38, 20.99)
# bottom_right point of  (21.1, 22.27) : (20.83, 21.22)
# top_left point of  (22.38, 20.99) : (21.42, 20.92)
# Distance between points: 0.6618912297349182
# Boxes to merge or not: True
# To merge or not to merge  down right level  True
# clustering id for 1st down right box 4
# calling clustering on (22.38, 20.99)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (22.38, 22.27)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (23.66, 22.27)
# checking for right 1st  level box
# 1st level right level =  (23.66, 20.99)
# checking for down right 1st  level box
# 1st level down right box =  (23.66, 19.71)
# checking for down 1st  level box
# 1st level down level =  (22.38, 19.71)
# bottom point of  (22.38, 20.99) : (21.92, 20.47)
# top point of  (22.38, 19.71) : (21.43, 19.14)
# Distance between points: 1.41739197119216
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 4
# calling clustering on (22.38, 19.71)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (22.38, 20.99)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (23.66, 20.99)
# checking for right 1st  level box
# 1st level right level =  (23.66, 19.71)
# checking for down right 1st  level box
# 1st level down right box =  (23.66, 18.43)
# checking for down 1st  level box
# 1st level down level =  (22.38, 18.43)
# Calling for Second level for down
# choosing 2nd level box down (22.38, 17.15)
# checking for left down 1st  level box
# 1st level down left box =  (21.1, 18.43)
# bottom_left point of  (22.38, 19.71) : (21.43, 19.14)
# top_right point of  (21.1, 18.43) : (20.71, 18.29)
# Distance between points: 1.113956911195402
# Boxes to merge or not: True
# To merge or not to merge left down level   True
# clustering id for 1st down left box 4
# calling clustering on (21.1, 18.43)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (21.1, 19.71)
# top point of  (21.1, 18.43) : (20.71, 18.29)
# bottom point of  (21.1, 19.71) : (19.85, 19.56)
# Distance between points: 1.533786165017796
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (21.1, 19.71) 4
# Flag details before checking flag  1 1
# Inside first if
# First level top box (21.1, 20.99)
# ...
# Distance between points: 0.36619666847201016
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (21.1, 20.99) 4
# Flag details before checking flag  1 1
# Inside first if
# First level top box (21.1, 22.27)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (22.38, 22.27)
# checking for right 1st  level box
# 1st level right level =  (22.38, 20.99)
# Calling for Second level for  right
# choosing 2nd level box right (23.66, 20.99)
# checking for down right 1st  level box
# 1st level down right box =  (22.38, 19.71)
# checking for down 1st  level box
# 1st level down level =  (21.1, 19.71)
# Calling for Second level for down
# choosing 2nd level box down (21.1, 18.43)
# checking for left down 1st  level box
# 1st level down left box =  (19.82, 19.71)
# bottom_left point of  (21.1, 20.99) : (20.06, 19.86)
# top_right point of  (19.82, 19.71) : (19.49, 19.6)
# Distance between points: 0.6264982043070828
# Boxes to merge or not: True
# To merge or not to merge left down level   True
# clustering id for 1st down left box 4
# calling clustering on (19.82, 19.71)
# Flag details before checking flag  1 1
# Inside first if
# First level top box (19.82, 20.99)
# top point of  (19.82, 19.71) : (19.17, 19.71)
# bottom point of  (19.82, 20.99) : (19.13, 19.84)
# Distance between points: 0.13601470508735428
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (19.82, 20.99) 4
# Flag details before checking flag  1 1
# Inside first if
# First level top box (19.82, 22.27)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (21.1, 22.27)
# checking for right 1st  level box
# 1st level right level =  (21.1, 20.99)
# Calling for Second level for  right
# choosing 2nd level box right (22.38, 20.99)
# checking for down right 1st  level box
# 1st level down right box =  (21.1, 19.71)
# checking for down 1st  level box
# 1st level down level =  (19.82, 19.71)
# Calling for Second level for down
# choosing 2nd level box down (19.82, 18.43)
# bottom point of  (19.82, 19.71) : (18.81, 19.04)
# top point of  (19.82, 18.43) : (19.13, 18.25)
# Distance between points: 0.8523496934944007
# Boxes to merge or not: True
# New cluster_id for down box jplus1 (19.82, 18.43) 4
# Calling clustering on down box second level
# Flag details before checking flag  1 1
# Inside first if
# First level top box (19.82, 19.71)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (21.1, 19.71)
# checking for right 1st  level box
# 1st level right level =  (21.1, 18.43)
# Calling for Second level for  right
# choosing 2nd level box right (22.38, 18.43)
# checking for down right 1st  level box
# 1st level down right box =  (21.1, 17.15)
# checking for down 1st  level box
# 1st level down level =  (19.82, 17.15)
# Calling for Second level for down
# choosing 2nd level box down (19.82, 15.87)
# checking for left down 1st  level box
# 1st level down left box =  (18.54, 17.15)
# checking for left 1st  level box
# 1st level left box =  (18.54, 18.43)
# Calling for Second level for left
# choosing 2nd level box up left  (17.26, 18.43)
# checking for up left 1st  level box
# 1st level up left box =  (18.54, 19.71)
# checking for left down 1st  level box
# 1st level down left box =  (18.54, 19.71)
# checking for left 1st  level box
# 1st level left box =  (18.54, 20.99)
# Calling for Second level for left
# choosing 2nd level box up left  (17.26, 20.99)
# checking for up left 1st  level box
# 1st level up left box =  (18.54, 22.27)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (21.1, 20.99)
# checking for right 1st  level box
# 1st level right level =  (21.1, 19.71)
# Calling for Second level for  right
# choosing 2nd level box right (22.38, 19.71)
# checking for down right 1st  level box
# 1st level down right box =  (21.1, 18.43)
# checking for down 1st  level box
# 1st level down level =  (19.82, 18.43)
# Calling for Second level for down
# choosing 2nd level box down (19.82, 17.15)
# checking for left down 1st  level box
# 1st level down left box =  (18.54, 18.43)
# checking for left 1st  level box
# 1st level left box =  (18.54, 19.71)
# Calling for Second level for left
# choosing 2nd level box up left  (17.26, 19.71)
# checking for up left 1st  level box
# 1st level up left box =  (18.54, 20.99)
# checking for left 1st  level box
# 1st level left box =  (19.82, 20.99)
# Calling for Second level for left
# choosing 2nd level box up left  (18.54, 20.99)
# checking for up left 1st  level box
# 1st level up left box =  (19.82, 22.27)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (22.38, 20.99)
# checking for right 1st  level box
# 1st level right level =  (22.38, 19.71)
# Calling for Second level for  right
# choosing 2nd level box right (23.66, 19.71)
# checking for down right 1st  level box
# 1st level down right box =  (22.38, 18.43)
# checking for down 1st  level box
# 1st level down level =  (21.1, 18.43)
# Calling for Second level for down
# choosing 2nd level box down (21.1, 17.15)
# checking for left down 1st  level box
# 1st level down left box =  (19.82, 18.43)
# checking for left 1st  level box
# 1st level left box =  (19.82, 19.71)
# Calling for Second level for left
# choosing 2nd level box up left  (18.54, 19.71)
# checking for up left 1st  level box
# 1st level up left box =  (19.82, 20.99)
# Calling for Second level for top box
# checking for top right 1st  level box
# 1st level top right level =  (22.38, 19.71)
# checking for right 1st  level box
# 1st level right level =  (22.38, 18.43)
# Calling for Second level for  right
# choosing 2nd level box right (23.66, 18.43)
# checking for down right 1st  level box
# 1st level down right box =  (22.38, 17.15)
# checking for down 1st  level box
# 1st level down level =  (21.1, 17.15)
# Calling for Second level for down
# choosing 2nd level box down (21.1, 15.87)
# checking for left down 1st  level box
# 1st level down left box =  (19.82, 17.15)
# checking for left 1st  level box
# 1st level left box =  (19.82, 18.43)
# Calling for Second level for left
# choosing 2nd level box up left  (18.54, 18.43)
# checking for up left 1st  level box
# 1st level up left box =  (19.82, 19.71)
# checking for left 1st  level box
# 1st level left box =  (21.1, 19.71)
# Calling for Second level for left
# choosing 2nd level box up left  (19.82, 19.71)
# checking for up left 1st  level box
# 1st level up left box =  (21.1, 20.99)
# Calling for Second level for down
# choosing 2nd level box down (22.38, 18.43)
# checking for left down 1st  level box
# 1st level down left box =  (21.1, 19.71)
# checking for left 1st  level box
# 1st level left box =  (21.1, 20.99)
# Calling for Second level for left
# choosing 2nd level box up left  (19.82, 20.99)
# checking for up left 1st  level box
# 1st level up left box =  (21.1, 22.27)
# checking for down 1st  level box
# 1st level down level =  (21.1, 20.99)
# Calling for Second level for down
# choosing 2nd level box down (21.1, 19.71)
# checking for left down 1st  level box
# 1st level down left box =  (19.82, 20.99)
# checking for left 1st  level box
# 1st level left box =  (19.82, 22.27)
# Calling for Second level for left
# choosing 2nd level box up left  (18.54, 22.27)
# checking for up left 1st  level box
# 1st level up left box =  (19.82, 23.55)
# Calling for Second level for  right
# choosing 2nd level box right (22.38, 22.27)
# checking for down right 1st  level box
# 1st level down right box =  (21.1, 20.99)
# checking for down 1st  level box
# 1st level down level =  (19.82, 20.99)
# Calling for Second level for down
# choosing 2nd level box down (19.82, 19.71)
# checking for left down 1st  level box
# 1st level down left box =  (18.54, 20.99)
# checking for left 1st  level box
# 1st level left box =  (18.54, 22.27)
# Calling for Second level for left
# choosing 2nd level box up left  (17.26, 22.27)
# checking for up left 1st  level box
# 1st level up left box =  (18.54, 23.55)
# checking for right 1st  level box
# 1st level right level =  (19.82, 20.99)
# Calling for Second level for  right
# choosing 2nd level box right (21.1, 20.99)
# checking for down right 1st  level box
# 1st level down right box =  (19.82, 19.71)
# checking for down 1st  level box
# 1st level down level =  (18.54, 19.71)
# Calling for Second level for down
# choosing 2nd level box down (18.54, 18.43)
# checking for left down 1st  level box
# 1st level down left box =  (17.26, 19.71)
# checking for left 1st  level box
# 1st level left box =  (17.26, 20.99)
# Calling for Second level for left
# choosing 2nd level box up left  (15.98, 20.99)
# checking for up left 1st  level box
# 1st level up left box =  (17.26, 22.27)
# Current Box: (18.54, 22.27)
# Current Box: (19.82, 4.35)
# Current Box: (19.82, 5.63)
# Current Box: (19.82, 6.91)
# Current Box: (19.82, 8.19)
# Current Box: (19.82, 9.47)
# Current Box: (19.82, 10.75)
# Current Box: (19.82, 12.03)
# Current Box: (19.82, 13.31)
# Current Box: (19.82, 14.59)
# Current Box: (19.82, 15.87)
# Current Box: (19.82, 17.15)
# Current Box: (19.82, 18.43)
# Current Box: (19.82, 19.71)
# Current Box: (19.82, 20.99)
# Current Box: (19.82, 22.27)
# Current Box: (21.1, 4.35)
# Current Box: (21.1, 5.63)
# Current Box: (21.1, 6.91)
# Current Box: (21.1, 8.19)
# Current Box: (21.1, 9.47)
# Current Box: (21.1, 10.75)
# Current Box: (21.1, 12.03)
# Current Box: (21.1, 13.31)
# Current Box: (21.1, 14.59)
# Current Box: (21.1, 15.87)
# Current Box: (21.1, 17.15)
# Current Box: (21.1, 18.43)
# Current Box: (21.1, 19.71)
# Current Box: (21.1, 20.99)
# Current Box: (21.1, 22.27)
# Current Box: (22.38, 4.35)
# Current Box: (22.38, 5.63)
# Current Box: (22.38, 6.91)
# Current Box: (22.38, 8.19)
# Current Box: (22.38, 9.47)
# Current Box: (22.38, 10.75)
# Current Box: (22.38, 12.03)
# Current Box: (22.38, 13.31)
# Current Box: (22.38, 14.59)
# Current Box: (22.38, 15.87)
# Current Box: (22.38, 17.15)
# Current Box: (22.38, 18.43)
# Current Box: (22.38, 19.71)
# Current Box: (22.38, 20.99)
# Current Box: (22.38, 22.27)
# {1: [(3.18, 4.34), (3.4, 4.35), (3.95, 4.31), (4.06, 3.69), (4.22, 3.18), (4.27, 4.2), (3.54, 4.39), (3.56, 4.63), (3.67, 5.04), (3.74, 4.56), (3.74, 5.0), (4.05, 4.54), (4.29, 5.34), (3.69, 6.51), (3.89, 6.56), (4.0, 6.48), (4.28, 6.15), (4.41, 6.6), (4.72, 3.98), (4.78, 4.3), (5.07, 3.07), (5.11, 3.08), (5.3, 3.64), (5.58, 4.0), (5.61, 3.53), (4.65, 4.45), (4.77, 4.66), (5.08, 4.53), (5.12, 5.16), (5.4, 5.22), (5.63, 5.47), (5.64, 4.5), (5.69, 5.29), (5.08, 5.7), (5.18, 5.99), (5.31, 5.86), (5.41, 6.07), (5.69, 5.71), (5.73, 5.94), (5.16, 6.93), (5.77, 4.88), (6.22, 4.69), (6.45, 4.83), (6.46, 5.16), (6.51, 4.73), (6.62, 5.4), (5.92, 6.27), (6.06, 6.68), (6.08, 6.28), (6.59, 5.74)], 0: [], 2: [(7.5, 8.12), (8.21, 7.26), (7.2, 8.42), (7.73, 8.33), (7.82, 8.54), (8.19, 9.37), (7.43, 9.9), (7.65, 9.81), (7.7, 9.57), (7.76, 10.52), (7.93, 9.48), (8.3, 7.28), (8.54, 7.08), (8.84, 7.04), (8.93, 8.15), (8.88, 8.92), (8.92, 9.31), (8.95, 9.47), (8.97, 9.27), (9.1, 8.25), (9.19, 9.05), (9.33, 8.39), (9.49, 8.65), (9.52, 9.08), (8.6, 9.6), (8.62, 9.68), (8.68, 9.72), (8.69, 9.64), (9.02, 9.83), (9.2, 9.79), (9.28, 10.19), (9.33, 10.44), (9.35, 10.65), (9.57, 10.63), (9.85, 8.07), (9.87, 7.37), (10.32, 8.07), (10.46, 7.64), (9.62, 8.72), (9.72, 8.73), (9.76, 8.43), (9.88, 8.43), (10.3, 8.27), (10.5, 8.77), (9.6, 10.29), (9.62, 9.97), (9.89, 10.42), (9.9, 10.25), (10.45, 10.33), (10.51, 10.03)], 3: [(14.19, 15.32), (14.54, 15.71), (14.13, 16.28), (14.24, 16.06), (14.27, 15.99), (14.61, 16.84), (15.33, 14.52), (14.77, 15.24), (14.94, 14.79), (15.62, 14.81), (15.8, 14.87), (15.94, 15.01), (14.86, 16.6), (15.08, 16.54), (15.34, 16.58), (15.37, 15.95), (15.43, 16.5), (15.46, 16.09), (15.58, 16.98), (15.68, 16.6), (15.76, 16.64), (15.86, 16.04), (15.92, 16.71), (14.82, 17.4), (15.72, 17.85), (15.79, 17.88), (15.99, 14.11), (16.29, 14.13), (16.02, 15.05), (16.13, 15.58), (16.18, 15.57), (16.3, 15.7), (16.4, 15.09), (16.5, 15.46), (16.63, 15.6), (16.82, 15.14), (17.16, 15.54), (16.15, 16.29), (16.72, 16.53), (17.03, 16.17), (17.1, 16.64), (16.1, 17.69), (16.5, 17.8), (17.26, 14.75), (17.64, 15.59), (17.3, 16.24), (17.51, 16.42), (17.54, 16.34), (17.69, 16.37), (17.94, 16.28)], 4: [(18.4, 19.91), (19.13, 18.25), (19.42, 18.27), (18.58, 19.24), (18.81, 19.04), (18.95, 19.42), (19.17, 19.71), (19.49, 19.6), (19.7, 19.02), (18.55, 20.63), (18.96, 20.28), (19.07, 20.73), (19.13, 20.18), (19.13, 19.84), (19.4, 20.34), (19.46, 20.61), (19.5, 20.42), (19.07, 21.58), (19.14, 21.42), (19.14, 21.21), (19.37, 21.16), (20.71, 18.29), (19.85, 19.56), (19.89, 20.29), (20.06, 19.86), (20.28, 20.24), (20.63, 20.14), (20.67, 20.82), (21.09, 19.99), (19.87, 21.11), (20.08, 21.11), (20.13, 21.84), (20.19, 21.32), (20.26, 21.09), (20.83, 21.22), (21.43, 19.14), (21.38, 20.75), (21.42, 20.92), (21.52, 20.51), (21.62, 20.88), (21.86, 20.56), (21.92, 20.47)]}
# Cluster_ID : 1
# Points : [(3.18, 4.34), (3.4, 4.35), (3.95, 4.31), (4.06, 3.69), (4.22, 3.18), (4.27, 4.2), (3.54, 4.39), (3.56, 4.63), (3.67, 5.04), (3.74, 4.56), (3.74, 5.0), (4.05, 4.54), (4.29, 5.34), (3.69, 6.51), (3.89, 6.56), (4.0, 6.48), (4.28, 6.15), (4.41, 6.6), (4.72, 3.98), (4.78, 4.3), (5.07, 3.07), (5.11, 3.08), (5.3, 3.64), (5.58, 4.0), (5.61, 3.53), (4.65, 4.45), (4.77, 4.66), (5.08, 4.53), (5.12, 5.16), (5.4, 5.22), (5.63, 5.47), (5.64, 4.5), (5.69, 5.29), (5.08, 5.7), (5.18, 5.99), (5.31, 5.86), (5.41, 6.07), (5.69, 5.71), (5.73, 5.94), (5.16, 6.93), (5.77, 4.88), (6.22, 4.69), (6.45, 4.83), (6.46, 5.16), (6.51, 4.73), (6.62, 5.4), (5.92, 6.27), (6.06, 6.68), (6.08, 6.28), (6.59, 5.74)]
# No. of points : 50
# Cluster_ID : 0
# Points : []
# No. of points : 0
# Cluster_ID : 2
# Points : [(7.5, 8.12), (8.21, 7.26), (7.2, 8.42), (7.73, 8.33), (7.82, 8.54), (8.19, 9.37), (7.43, 9.9), (7.65, 9.81), (7.7, 9.57), (7.76, 10.52), (7.93, 9.48), (8.3, 7.28), (8.54, 7.08), (8.84, 7.04), (8.93, 8.15), (8.88, 8.92), (8.92, 9.31), (8.95, 9.47), (8.97, 9.27), (9.1, 8.25), (9.19, 9.05), (9.33, 8.39), (9.49, 8.65), (9.52, 9.08), (8.6, 9.6), (8.62, 9.68), (8.68, 9.72), (8.69, 9.64), (9.02, 9.83), (9.2, 9.79), (9.28, 10.19), (9.33, 10.44), (9.35, 10.65), (9.57, 10.63), (9.85, 8.07), (9.87, 7.37), (10.32, 8.07), (10.46, 7.64), (9.62, 8.72), (9.72, 8.73), (9.76, 8.43), (9.88, 8.43), (10.3, 8.27), (10.5, 8.77), (9.6, 10.29), (9.62, 9.97), (9.89, 10.42), (9.9, 10.25), (10.45, 10.33), (10.51, 10.03)]
# No. of points : 50
# Cluster_ID : 3
# Points : [(14.19, 15.32), (14.54, 15.71), (14.13, 16.28), (14.24, 16.06), (14.27, 15.99), (14.61, 16.84), (15.33, 14.52), (14.77, 15.24), (14.94, 14.79), (15.62, 14.81), (15.8, 14.87), (15.94, 15.01), (14.86, 16.6), (15.08, 16.54), (15.34, 16.58), (15.37, 15.95), (15.43, 16.5), (15.46, 16.09), (15.58, 16.98), (15.68, 16.6), (15.76, 16.64), (15.86, 16.04), (15.92, 16.71), (14.82, 17.4), (15.72, 17.85), (15.79, 17.88), (15.99, 14.11), (16.29, 14.13), (16.02, 15.05), (16.13, 15.58), (16.18, 15.57), (16.3, 15.7), (16.4, 15.09), (16.5, 15.46), (16.63, 15.6), (16.82, 15.14), (17.16, 15.54), (16.15, 16.29), (16.72, 16.53), (17.03, 16.17), (17.1, 16.64), (16.1, 17.69), (16.5, 17.8), (17.26, 14.75), (17.64, 15.59), (17.3, 16.24), (17.51, 16.42), (17.54, 16.34), (17.69, 16.37), (17.94, 16.28)]
# No. of points : 50
# Cluster_ID : 4
# Points : [(18.4, 19.91), (19.13, 18.25), (19.42, 18.27), (18.58, 19.24), (18.81, 19.04), (18.95, 19.42), (19.17, 19.71), (19.49, 19.6), (19.7, 19.02), (18.55, 20.63), (18.96, 20.28), (19.07, 20.73), (19.13, 20.18), (19.13, 19.84), (19.4, 20.34), (19.46, 20.61), (19.5, 20.42), (19.07, 21.58), (19.14, 21.42), (19.14, 21.21), (19.37, 21.16), (20.71, 18.29), (19.85, 19.56), (19.89, 20.29), (20.06, 19.86), (20.28, 20.24), (20.63, 20.14), (20.67, 20.82), (21.09, 19.99), (19.87, 21.11), (20.08, 21.11), (20.13, 21.84), (20.19, 21.32), (20.26, 21.09), (20.83, 21.22), (21.43, 19.14), (21.38, 20.75), (21.42, 20.92), (21.52, 20.51), (21.62, 20.88), (21.86, 20.56), (21.92, 20.47)]
# No. of points : 42
# Accuracy:  0.8
# Counter({0: 184, 3: 12, 4: 11, 1: 9, 2: 9})
# --- 0.8276991844177246 seconds in super_cube dbscan---

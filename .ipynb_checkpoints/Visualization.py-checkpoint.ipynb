# %%
import copy
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pylab
import math
from itertools import product
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import time
import sys
start_time = time.time()
import decimal
import scipy.spatial as spatial
from collections import Counter
import itertools
import sys
sys.setrecursionlimit(1000)
epsilon = 1.28
min_points = 4.0  # float(sys.argv[3])


# points,neighbours,merging distance,position,flag,cluster_id,hot_cold,visited
def supercube_dbscan():
    # Take input from file (Copy Paste from dbscan code) and sort acc. to x and  y axis
    # open the dataset
    file_name = "dataset1.csv"
    i = open(file_name)
    lines = i.read().strip().split('\n')
    i.close()
    # initialize the list in which your dataset will be stored in the form of list
    dataset = {}
    coord = []
    dim_size = 2  # int(sys.argv[1]) #float(sys.argv[2])
    min_points = 4.0  # float(sys.argv[3])
    # Sort
    for i in range(dim_size):
        coord.append([])
    for i in lines:
        line = i.rstrip().split(',')
        temp = []
        # extract x and y coordinates
        for j in line:
            temp.append(j.strip())
        # print temp
        # convert to float if the input is not numeric type
        for i in range(dim_size):
            temp[i] = float(temp[i])
            coord[i].append(round(temp[i],2))
        # can't use list as keys so converting to tuple
        temp = tuple(temp)
        # print len(dataset)
        # default not visited that's why 0
        dataset[temp] = 0
    data = list(sorted(dataset.keys(), key=lambda t: t[0]))
    data = re_round(data)
    #print data
    start_box_coord = []
    start_box_coord.append(round(min(coord[0]), 2))  # left most point in dataset(0)
    start_box_coord.append(round(max(coord[0]), 2))  # right most point in dataset(1)
    start_box_coord.append(round(max(coord[1]), 2))  # top most point in dataset(2)
    start_box_coord.append(round(min(coord[1]), 2))  # bottom most point in dataset(3)
    #print start_box_coord
    len_x = round(abs(start_box_coord[1] - start_box_coord[0]), 2)  # total length of x-axis
    len_y = round(abs(start_box_coord[2] - start_box_coord[3]), 2)
    # total length of y-axis
    number_box_x = int(math.ceil(len_x / round((epsilon / 1.41), 2)))  # epsilon/rt(2)=1.27
    number_box_y = int(math.ceil(len_y / round((epsilon / 1.41), 2)))
    len_x = number_box_x * round(epsilon / 1.41, 2)
    len_y = number_box_y * round(epsilon / 1.41, 2)
    #print round(epsilon / 1.41, 2)
    # len_x,len_y
    '''fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(coord[0], coord[1], cmap=plt.hot())
    plt.plot([start_box_coord[0],start_box_coord[1],start_box_coord[1],start_box_coord[0],start_box_coord[0]], [start_box_coord[2],start_box_coord[2],start_box_coord[3],start_box_coord[3],start_box_coord[2]], 'r-')
    plt.show()'''
    
    plt.xticks(np.arange(3.13, 22.33, 1.28))
    plt.yticks(np.arange(3.07, 22.27, 1.28))
    plt.scatter(coord[0],coord[1])
    plt.grid(True)
    matplotlib.rcParams.update({'font.size': 10})
    plt.text(4.94, 2.64, r'4.94, 2.64')

    plt.show()
    no_k_bands = number_box_x
    no_l_bands = number_box_y
    k_bands = []
    l_bands = []
    k_bands.append(round(start_box_coord[0] + round(epsilon / 1.41, 2),2))
    l_bands.append(round(start_box_coord[3] + round(epsilon / 1.41, 2),2))
    for i in range(1, no_k_bands):
        temp = k_bands[i - 1] + round((epsilon / 1.41), 2)
        #print temp
        k_bands.append(round(temp, 2))
    for j in range(1, no_l_bands):
        temp1 = l_bands[j - 1] + round((epsilon / 1.41), 2)
        #print temp1
        l_bands.append(round(temp1, 2))
    #print k_bands,l_bands
    # creating the boxes
    box_list = list(itertools.product(k_bands, l_bands))
    # print box_list
    # print(len(box_list))
    # 0 for corner,1 for edge,2 for middle
    box_details = {}
    merge_points = []
    open_flag = 0
    cluster_id = 0
    hot_cold = 0
    visited=0
    for i in range(8):
        merge_points.append((-999, -999))
    box_start_coord = []
    box_start_coord.append(k_bands[0])
    box_start_coord.append(k_bands[number_box_x - 1])
    box_start_coord.append(l_bands[number_box_y - 1])
    box_start_coord.append(l_bands[0])
    # print box_start_coord
    # print start_box_coord
    for n in box_list:
        # print n
        if (n[0] == box_start_coord[0] or n[0] == box_start_coord[1] or n[1] == box_start_coord[2] or n[1] ==
            box_start_coord[3]):
            #print("corner cases")
            #print"####################################################################")
            if ((n[0] == box_start_coord[0] and n[1] == box_start_coord[2])):
                print("______________________________________________________")
                neighbour = re_round([(n[0] + round((epsilon / 1.41), 2), n[1]), (
                n[0] + round((epsilon / 1.41), 2), n[1] + round((epsilon / 1.41), 2)),
                                      (n[0], n[1] + round((epsilon / 1.41), 2))])
                box_details[n] = [[], neighbour, merge_points, 0, open_flag, cluster_id,
                                  hot_cold,visited]  # points,neighbours,merging distance,position,flag,cluster_id,hot_cold
            elif ((n[0] == box_start_coord[1] and n[1] == box_start_coord[2])):
                #print("++++++++++++++++++++++++++++++++++++++++++++++++++++++")
                neighbour = re_round([(n[0] - round((epsilon / 1.41), 2), n[1]), (
                n[0] - round((epsilon / 1.41), 2), n[1] - round((epsilon / 1.41), 2)),
                                      (n[0], n[1] - round((epsilon / 1.41), 2))])
                box_details[n] = [[], neighbour, merge_points, 0, open_flag, cluster_id, hot_cold,visited]
            elif ((n[0] == box_start_coord[1] and n[1] == box_start_coord[3])):
                #print("&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&")
                neighbour = re_round([(n[0], n[1] + round((epsilon / 1.41), 2)),
                                      (n[0] - round((epsilon / 1.41), 2), n[1]), (
                                      n[0] - round((epsilon / 1.41), 2),
                                      n[1] + round((epsilon / 1.41), 2))])
                box_details[n] = [[], neighbour, merge_points, 0, open_flag, cluster_id, hot_cold,visited]
            elif ((n[0] == box_start_coord[0] and n[1] == box_start_coord[3])):
                #print("-------------------------------------------------------")
                neighbour = re_round([(n[0], n[1] + round((epsilon / 1.41), 2)), (
                n[0] + round((epsilon / 1.41), 2), n[1] + round((epsilon / 1.41), 2)),
                                      (n[0] + round((epsilon / 1.41), 2), n[1])])
                box_details[n] = [[], neighbour, merge_points, 0, open_flag, cluster_id, hot_cold,visited]
            else:
                #print("edge case")
                if (n[0] == box_start_coord[0]):  # left side
                    neighbour = re_round([(n[0], n[1] + round((epsilon / 1.41), 2)), (
                    n[0] - round((epsilon / 1.41), 2), n[1] + round((epsilon / 1.41), 2)),
                                          (n[0] - round((epsilon / 1.41), 2), n[1]), (
                                          n[0] - round((epsilon / 1.41), 2),
                                          n[1] - round((epsilon / 1.41), 2)),
                                          (n[0], n[1] - round((epsilon / 1.41), 2))])
                    box_details[n] = [[], neighbour, merge_points, 1, open_flag, cluster_id, hot_cold,visited]
                elif (n[1] == box_start_coord[2]):  # top side
                    neighbour = re_round([(n[0] - round((epsilon / 1.41), 2), n[1]), (
                    n[0] - round((epsilon / 1.41), 2), n[1] - round((epsilon / 1.41), 2)),
                                          (n[0], n[1] - round((epsilon / 1.41), 2)), (
                                          n[0] + round((epsilon / 1.41), 2),
                                          n[1] - round((epsilon / 1.41), 2)),
                                          (n[0] + round((epsilon / 1.41), 2), n[1])])
                    box_details[n] = [[], neighbour, merge_points, 1, open_flag, cluster_id, hot_cold,visited]
                elif (n[0] == box_start_coord[1]):  # right side
                    # print ""
                    neighbour = re_round([(n[0], n[1] + round((epsilon / 1.41), 2)),
                                          (n[0], n[1] - round((epsilon / 1.41), 2)), (
                                          n[0] - round((epsilon / 1.41), 2),
                                          n[1] + round((epsilon / 1.41), 2)),
                                          (n[0] - round((epsilon / 1.41), 2), n[1]), (
                                          n[0] - round((epsilon / 1.41), 2),
                                          n[1] - round((epsilon / 1.41), 2))])
                    box_details[n] = [[], neighbour, merge_points, 1, open_flag, cluster_id, hot_cold,visited]
                else:  # bottom side
                    # print ""
                    neighbour = re_round([(n[0] - round((epsilon / 1.41), 2), n[1]),
                                          (n[0] + round((epsilon / 1.41), 2), n[1]),
                                          (n[0], n[1] + round((epsilon / 1.41), 2)), (
                                          n[0] - round((epsilon / 1.41), 2),
                                          n[1] + round((epsilon / 1.41), 2)), (
                                          n[0] + round((epsilon / 1.41), 2),
                                          n[1] + round((epsilon / 1.41), 2))])
                    box_details[n] = [[], neighbour, merge_points, 1, open_flag, cluster_id, hot_cold,visited]
        else:
            neighbour = re_round(
                [(n[0] - round((epsilon / 1.41), 2), n[1] + round((epsilon / 1.41), 2)),
                 (n[0], n[1] + round((epsilon / 1.41), 2)),
                 (n[0] + round((epsilon / 1.41), 2), n[1] + round((epsilon / 1.41), 2)),
                 (n[0] - round((epsilon / 1.41), 2), n[1]), (n[0] + round((epsilon / 1.41), 2), n[1]),
                 (n[0] - round((epsilon / 1.41), 2), n[1] - round((epsilon / 1.41), 2)),
                 (n[0], n[1] - round((epsilon / 1.41), 2)),
                 (n[0] + round((epsilon / 1.41), 2), n[1] - round((epsilon / 1.41), 2))])
            box_details[n] = [[], neighbour, merge_points, 2, open_flag, cluster_id, hot_cold,visited]
    # for i in box_details.keys():
    #    print i," ke neighbours hai ---> ",box_details[i][1]
    '''k_bands.append(3.13)
    l_bands.append(3.07)
    v=list ( itertools.product(k_bands,l_bands) )
    print v
    l=[]
    p=[]
    for i in v:
        l.append(i[0])
        p.append(i[1])
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(coord[0], coord[1], cmap=plt.hot())
    plt.plot(l,p,'go')
    plt.show()'''
    count = 0
    print(box_details)
    for j in data:
        # print j
        count = count + 1
        # print coun
        # check for mode over here
        p = (j[0] - start_box_coord[0])
        q = (j[1] - start_box_coord[3])
        if p == 0:
            p = 1
        elif q == 0:
            q = 1
        else:
            p = p
            q = q
        mov_x = math.ceil(p / round((epsilon / 1.41), 2))
        mov_y = math.ceil(q / round((epsilon / 1.41), 2))
        a = (mov_x * round((epsilon / 1.41), 2)) + start_box_coord[0]
       # print a
        b = (mov_y * round((epsilon / 1.41), 2)) + start_box_coord[3]
        #print b
        a = re_round(a)
        b = re_round(b)
        #print  "point :", j
        #print "box:",a,b
        tp = box_details[a, b][0]
        # print "points already present:",tp
        check = box_details[a, b][4]
        # print "already visited:",check
        # print "box contents:",box_details
        if (not check):
            # print (a,b),j
            box_details[a, b][4] = 1
            list_t = []
            for _ in range(8):
                list_t.append(j)
            box_details[a, b][2] = copy.deepcopy(list_t)
        else:
            top_id=(a-round((epsilon / (2*1.41)), 2),b)
            bottom_id=(a-round((epsilon / (2*1.41)), 2),b-round((epsilon / 1.41), 2))
            left_id=(a-round((epsilon / (1.41)), 2),b-round((epsilon / (2*1.41)), 2))
            right_id=(a,b-round((epsilon / (2*1.41)), 2))
            lefttop_id=(a-round((epsilon / 1.41), 2),b)
            righttop_id=(a,b)
            leftbottom_id=(a-round((epsilon / 1.41), 2),b-round((epsilon / 1.41), 2))
            rightbottom_id=(a,b-round((epsilon / 1.41), 2))
            lefttop_d=euclidean(lefttop_id,box_details[a, b][2][0])
            top_d=euclidean(top_id,box_details[a, b][2][1])
            righttop_d=euclidean(righttop_id,box_details[a, b][2][2])
            left_d=euclidean(left_id,box_details[a, b][2][3])
            right_d=euclidean(right_id,box_details[a, b][2][4])
            leftbottom_d=euclidean(leftbottom_id,box_details[a, b][2][5])
            bottom_d=euclidean(bottom_id,box_details[a, b][2][6])
            rightbottom_d=euclidean(rightbottom_id,box_details[a, b][2][7])
            new_lefttop_d=euclidean(lefttop_id,j)
            new_top_d=euclidean(top_id,j)
            new_righttop_d=euclidean(righttop_id,j)
            new_left_d=euclidean(left_id,j)
            new_right_d=euclidean(right_id,j)
            new_leftbottom_d=euclidean(leftbottom_id,j)
            new_bottom_d=euclidean(bottom_id,j)
            new_rightbottom_d=euclidean(rightbottom_id,j)
            #print j,a, b, top_d, new_top_d,box_details[a, b][2][1],top_id
            if(lefttop_d>new_lefttop_d):
                #print a,b,lefttop_d,new_lefttop_d
                box_details[a, b][2][0]=j
            if(top_d>new_top_d):
                #print a,b,top_d,new_top_d
                box_details[a, b][2][1]=j
            if(righttop_d>new_righttop_d):
                box_details[a, b][2][2]=j
            if(leftbottom_d>new_leftbottom_d):
                box_details[a, b][2][5]=j
            if(left_d>new_left_d):
                box_details[a, b][2][3]=j
            if(right_d>new_right_d):
                box_details[a, b][2][4]=j
            if(bottom_d>new_bottom_d):
                box_details[a, b][2][6]=j
            if(rightbottom_d>new_rightbottom_d):
                box_details[a, b][2][7]=j
            '''
            if (j[0] < box_details[a, b][2][3][0]):
                box_details[a, b][2][3] = j
            else:
                left_a = (a - round((epsilon / 1.41), 2), b / 2)
                i = box_details[a, b][2][3]
                temp1 = euclidean(j, left_a)
                temp2 = euclidean(i, left_a)

                if(temp1>temp2):
                    box_details[a, b][2][3]=i
                else:
                    box_details[a, b][2][3]=j
            if (j[0] > box_details[a, b][2][4][0]):
                box_details[a, b][2][4] = j
            else:
                right_a = (a, b / 2)
                i = box_details[a, b][2][4]
                temp1 = euclidean(j, right_a)
                temp2 = euclidean(i, right_a)
                if (temp1 > temp2):
                    box_details[a, b][2][4] = i
                else:
                    box_details[a, b][2][4] = j
            if (j[1] > box_details[a, b][2][1][1]):
                box_details[a, b][2][1] = j
            else:
                top_a = (a / 2, b)
                i=box_details[a, b][2][1]
                temp1=euclidean(j,top_a)
                temp2=euclidean(i,top_a)
                if (temp1 > temp2):
                    box_details[a, b][2][1] = i
                else:
                    box_details[a, b][2][1] = j
            if (j[1] < box_details[a, b][2][6][1]):
                box_details[a, b][2][6] = j
            else:
                bottom_a=(a/2,b-round((epsilon / 1.41), 2))
                i=box_details[a, b][2][6]
                temp1=euclidean(j,bottom_a)
                temp2=euclidean(i,bottom_a)
                if (temp1 > temp2):
                    box_details[a, b][2][6] = i
                else:
                    box_details[a, b][2][6] = j
            if (j[0]) <= (box_details[a, b][2][0][0]) and (j[1] >= box_details[a, b][2][0][1]):
                box_details[a, b][2][0] = j
            if j[0] >= box_details[a, b][2][2][0] and j[1] >= box_details[a, b][2][2][1]:
                box_details[a, b][2][2] = j
            if (j[0] <= box_details[a, b][2][5][0] and j[1] <= box_details[a, b][2][5][1]):
                box_details[a, b][2][5] = j
            if (j[0] >= box_details[a, b][2][7][0] and j[1] <= box_details[a, b][2][7][1]):
                box_details[a, b][2][7] = j

            '''
            '''
            #print box_details[a,b][2][0]
            box_details[a,b][2][1]=j
            box_details[a,b][2][2]=j
            box_details[a,b][2][3] = j
            box_details[a,b][2][4] = j
            box_details[a,b][2][5] = j
            box_details[a,b][2][6] = j
            box_details[a,b][2][7] = j
            check=0
            '''
        # print tp
        # print "box contents:",box_details
        # print "merging points:",box_details[a,b][2]
        tp.append(j)
        # print "current points:",tp
        box_details[a, b][0] = tp
        # print "points in box:",box_details[a,b][0]
        # print "box contents:",box_details
    #print box_details
    # print data
    # for i in box_details.keys():
    # print i,box_details[i][0]
    # 0=cold
    #cluster_id=count
    count = 1
    hot=1
    print(box_details)
    for i in box_details.keys():
        if(not box_details[i][7] and box_details[i][4]):
            print("Current Box:",i)
            box_details[i][6]=1
            box_details[i][5] = count
            print("Cluster_id before calling clustering on box ",i,":",box_details[i][5])

            clustering(box_details, i)
            count = count + 1
    print(box_details)
    cluster_list=[]
    for i in box_details.keys():
        temp=box_details[i][5]
        cluster_list.append(temp)
    print(Counter(cluster_list))
    print("--- %s seconds in supercube_dbscan---" % (time.time() - start_time))




def clustering(box_details, i):
    visited=box_details[i][7]
    if(not visited):
        box_details[i][7]=1
        open_flag = box_details[i][4]
        hot_flag = box_details[i][6]
        print("Flag details before checking flag ",open_flag,hot_flag)
        if (open_flag and hot_flag):
            print("Inside first if")
            print("Checking for top box")
            j = (i[0], i[1] + round(epsilon / 1.41, 2))
            print("First level top box",j)
            if (j in box_details.keys()):
                if(box_details[j][4] and not box_details[j][7]):
                    flag = check_up(i, box_details, j)
                    print("To merge or not to merge first level top box",flag)
                    if (flag):
                        box_details[j][6] = 1  # hot
                        box_details[j][5] = box_details[i][5]
                        print("Calling clustering on 1st level top box",j,box_details[i][5])
                        clustering(box_details, j)
                    else:
                        print("checking for j+1 box")
                        print("Calling for Second level for top box")
                        jplus1 = (j[0], j[1] + round(epsilon / 1.41, 2))
                        if (jplus1 in box_details.keys()):
                            if (box_details[jplus1][4] and not box_details[jplus1][7]):
                                print("Second Level box:",jplus1)
                                flag = check_up(j, box_details, jplus1)
                                print("To merge or not to merge second level top box",flag)
                                if (flag):
                                    box_details[jplus1][6] = 1  # hot
                                    box_details[jplus1][5] = box_details[j][5]
                                    print("New cluster_id for top box jplus1",jplus1,box_details[jplus1][5])
                                    print("Calling clustering on top box second level")
                                    clustering(box_details, jplus1)

            print("Checking for up right")
            print("checking for top right 1st  level box ")
            j = (i[0] + round(epsilon / 1.41, 2), i[1] + round(epsilon / 1.41, 2))
            print("1st level top right level = ",j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):
                    flag = check_up_right(i, box_details, j)
                    print("To merge or not to merge top right level ", flag)
                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st top right box",box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                    else:
                        print("checking for j+1 box")
                        print("Calling for Second level for top right")
                        jplus1 = (j[0] + round(epsilon / 1.41, 2), j[1] + round(epsilon / 1.41, 2))
                        print("choosing 2nd level box top right", jplus1)
                        if (jplus1 in box_details.keys()):
                            if (box_details[jplus1][4] and not box_details[jplus1][7]):
                                print("Second Level box:", jplus1)
                                flag = check_up_right(j, box_details, jplus1)
                                print("To merge or not to merge second level top right ",flag)
                                if (flag):
                                    box_details[jplus1][6] = 1
                                    box_details[jplus1][5] = box_details[j][5]
                                    print("New cluster_id for up right box jplus1",jplus1,box_details[jplus1][5])
                                    print("Calling clustering on top right box second level")
                                    clustering(box_details, jplus1)

            print("Checking for right")
            print("checking for right 1st  level box ")
            j = (i[0] + round(epsilon / 1.41, 2), i[1])
            print("1st level right level = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):

                    flag=check_right(i, box_details, j)
                    print("To merge or not to merge right level ", flag)
                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st right box",box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                    else:
                        print("Calling for Second level for  right")
                        jplus1 = (j[0] + round(epsilon / 1.41, 2), j[1])
                        print("choosing 2nd level box right", jplus1)
                        if (jplus1 in box_details.keys()):
                            if (box_details[jplus1][4] and not box_details[jplus1][7]):
                                print("Second Level box:", jplus1)
                                flag=check_right(j, box_details, jplus1)
                                print("To merge or not to merge second level right ", flag)
                                if (flag):
                                    box_details[jplus1][6] = 1
                                    box_details[jplus1][5] = box_details[j][5]
                                    print("New cluster_id for right box jplus1",jplus1,box_details[jplus1][5])
                                    print("Calling clustering on right box second level")
                                    clustering(box_details, jplus1)

            print("Checking for down right")
            print("checking for down right 1st  level box ")
            j = (i[0] + round(epsilon / 1.41, 2), i[1] - round(epsilon / 1.41, 2))
            print("1st level down right box = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):

                    flag=check_down_right(i, box_details, j)
                    print("To merge or not to merge  down right level ", flag)

                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st down right box",box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                    else:
                        print("Calling for Second level for down right")
                        # check for j+1
                        jplus1 = (j[0] + round(epsilon / 1.41, 2), j[1] - round(epsilon / 1.41, 2))
                        print("choosing 2nd level box down right", jplus1)
                        if (jplus1 in box_details.keys()):
                            if (box_details[jplus1][4] and not box_details[jplus1][7]):
                                flag=check_down_right(j, box_details, jplus1)
                                if (flag):
                                    box_details[jplus1][6] = 1
                                    box_details[jplus1][5] = box_details[j][5]
                                    print("New cluster_id for down right box jplus1",jplus1,box_details[jplus1][5])
                                    print("Calling clustering on down right box second level")
                                    clustering(box_details, jplus1)

            print("Checking for down")
            print("checking for down 1st  level box ")
            j = (i[0], i[1] - round(epsilon / 1.41, 2))
            print("1st level down level = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):
                    flag=check_down(i, box_details, j)
                    print("To merge or not to merge  down level ", flag)
                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st down box",box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                    else:
                        print("Calling for Second level for down ")
                        print("check for j+1")
                        jplus1 = (j[0], j[1] - round(epsilon / 1.41, 2))
                        print("choosing 2nd level box down", jplus1)
                        if (jplus1 in box_details.keys()):
                            if (box_details[jplus1][4] and not box_details[jplus1][7]):
                                flag=check_down(j, box_details, jplus1)
                                if (flag):
                                    box_details[jplus1][6] = 1
                                    box_details[jplus1][5] = box_details[j][5]
                                    print("New cluster_id for down box jplus1",jplus1,box_details[jplus1][5])
                                    print("Calling clustering on down box second level")
                                    clustering(box_details, jplus1)

            print("Checking for down left")
            print("checking for left down 1st  level box ")
            j = (i[0] - round(epsilon / 1.41, 2), i[1] - round(epsilon / 1.41, 2))
            print("1st level down left box = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):

                    flag=check_down_left(i, box_details, j)
                    print("To merge or not to merge left down level  ", flag)

                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st down left box", box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                    else:
                        print("Calling for Second level for down left")
                        print("check for j+1")
                        jplus1 = (i[0] - round(epsilon / 1.41, 2), i[1] - round(epsilon / 1.41, 2))
                        print("choosing 2nd level box down left", jplus1)
                        if (jplus1 in box_details.keys()):
                            if (box_details[jplus1][4] and not box_details[jplus1][7]):
                                flag=check_down_left(j, box_details, jplus1)
                                if (flag):
                                    box_details[jplus1][6] = 1
                                    box_details[jplus1][5] = box_details[j][5]
                                    print("New cluster_id for down left box jplus1",jplus1,box_details[jplus1][5])
                                    print("Calling clustering on down left box second level")
                                    clustering(box_details, jplus1)

            print("Checking for left")
            print("checking for left 1st  level box ")
            j = (i[0] - round(epsilon / 1.41, 2), i[1])
            print("1st level left box = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):
                    flag=check_left(i, box_details, j)
                    print("To merge or not to merge left level  ", flag)
                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st left box", box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                    else:
                        print("Calling for Second level for left")
                        print("check for j+1 box")
                        jplus1 = (j[0] - round(epsilon / 1.41, 2), j[1])
                        print("choosing 2nd level box up left ", jplus1)
                        if (jplus1 in box_details.keys()):
                            if (box_details[jplus1][4] and not box_details[jplus1][7]):
                                flag=check_left(j, box_details, jplus1)
                                if (flag):
                                    box_details[jplus1][6] = 1
                                    box_details[jplus1][5] = box_details[j][5]
                                    print("New cluster_id for left  box jplus1",jplus1,box_details[jplus1][5])
                                    print("Calling clustering on left box second level")
                                    clustering(box_details, jplus1)

            print("checking for up left")
            print("checking for up left 1st  level box ")
            j = (i[0] - round(epsilon / 1.41, 2), i[1] + round(epsilon / 1.41, 2))
            print("1st level up left box = ", j)
            if (j in box_details.keys()):
                if (box_details[j][4] and not box_details[j][7]):
                    flag=check_up_left(i, box_details, j)
                    print("To merge or not to merge up left level  ", flag)
                    if (flag):
                        box_details[j][6] = 1
                        box_details[j][5] = box_details[i][5]
                        print("clustering id for 1st top left box", box_details[i][5])
                        print("calling clustering on", j)
                        clustering(box_details, j)
                    else:
                        print("Calling for Second level for left up")
                        print("check for j+1")
                        jplus1 = (j[0] - round(epsilon / 1.41, 2), j[1] + round(epsilon / 1.41, 2))
                        print("choosing 2nd level box up left ", jplus1)
                        if (jplus1 in box_details.keys()):
                            if (box_details[jplus1][4] and not box_details[jplus1][7]):
                                flag=check_up_left(j, box_details, jplus1)
                                if (flag):
                                    box_details[jplus1][6] = 1
                                    box_details[jplus1][5] = box_details[j][5]
                                    print("New cluster_id for up left box jplus1",jplus1,box_details[jplus1][5])
                                    print("Calling clustering on up left box second level")
                                    clustering(box_details, jplus1)
    return

def check_up(box_coord, box_details, check_box):
    flag = False
    top = box_details[box_coord][2][1]
    print("top point of ",box_coord,":",top)
    bottom = box_details[check_box][2][6]
    print("bottom point of ",check_box, ":", bottom)
    #print top,bottom
    dist = euclidean(top,bottom)
    print("Distance between points:",dist)
    if (dist < epsilon):
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag


def check_up_right(box_coord, box_details, check_box):
    flag = False
    top_right = box_details[box_coord][2][2]  # add correct values
    print("top_right point of ", box_coord, ":", top_right)
    bottom_left = box_details[check_box][2][5]  # add correct values
    print("bottom_left point of ",check_box, ":", bottom_left)
    dist = euclidean(top_right,bottom_left)
    print("Distance between points:",dist)

    #print dist
    if (dist < epsilon ):
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag

def check_right(box_coord, box_details, check_box):
    flag = False
    right = box_details[box_coord][2][4]  # add correct values
    print("right point of ", box_coord, ":", right)
    left = box_details[check_box][2][3]  # add correct values
    print("left point of ", check_box, ":", left)

    dist = euclidean(right,left)
    print("Distance between points:",dist)

    #print dist
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
    if (dist < epsilon ):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag

def check_down_right(box_coord, box_details, check_box):
    flag = False
    bottom_right = box_details[box_coord][2][7]  # add correct values
    print("bottom_right point of ", box_coord, ":", bottom_right)
    top_left = box_details[check_box][2][0]  # add correct values
    print("top_left point of ", check_box, ":", top_left)
    dist=euclidean(bottom_right,top_left)
    print("Distance between points:",dist)

    if (dist < epsilon ):
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag

def check_down(box_coord, box_details, check_box):
    flag = False
    bottom = box_details[box_coord][2][6]  # add correct values
    print("bottom point of ", box_coord, ":", bottom)
    top = box_details[check_box][2][1]  # add correct values
    print("top point of ", check_box, ":", top)
    dist = euclidean(bottom,top)
    print("Distance between points:",dist)

    #print dist
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
    if (dist < epsilon ):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag

def check_down_left(box_coord, box_details, check_box):
    flag = False
    bottom_left = box_details[box_coord][2][5]  # add correct values
    print("bottom_left point of ", box_coord, ":", bottom_left)
    top_right = box_details[check_box][2][2]  # add correct values
    print("top_right point of ", check_box, ":", top_right)
    dist = euclidean(bottom_left,top_right)
    print("Distance between points:",dist)
    #print dist
    if (dist < epsilon ):
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
        flag = True
    print("Boxes to merge or not:",flag)

    return flag

def check_left(box_coord, box_details, check_box):
    flag = False
    left = box_details[box_coord][2][3]  # add correct values
    print("left point of ", box_coord, ":", left)
    right = box_details[check_box][2][4]  # add correct values
    print("right point of ", check_box, ":", right)
    dist = euclidean(left,right)
    print("Distance between points:",dist)
    #print dist
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
    if (dist < epsilon ):
        flag = True
    print("Boxes to merge or not:", flag)
    return flag

def check_up_left(box_coord, box_details, check_box):
    flag = False
    top_left = box_details[box_coord][2][0]  # add correct values
    print("top_left point of ", box_coord, ":", top_left)
    bottom_right = box_details[check_box][2][7]  # add correct values
    print("bottom_right point of ", check_box, ":", bottom_right)
    dist = euclidean(top_left,bottom_right)
    print("Distance between points:",dist)
    #print dist
    #if (dist < epsilon and len(box_details[box_coord][0]) > min_points):
    if (dist < epsilon ):
        flag = True
    print("Boxes to merge or not:",flag)
    return flag


def euclidean(x, y):
    sumSq = 0.0

    # add up the squared differences
    for i in range(len(x)):
        sumSq += (x[i] - y[i]) ** 2

    # take the square root of the result
    return sumSq ** 0.5
# round off
def re_round(li, _prec=2):
    try:
        return round(li, _prec)
    except TypeError:
        return type(li)(re_round(x, _prec) for x in li)


supercube_dbscan()
# Out:
# ______________________________________________________
# {(4.04, 3.98): [[], [(4.04, 4.89), (4.95, 4.89), (4.95, 3.98)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 0, 0, 0, 0, 0], (4.04, 4.89): [[], [(4.04, 5.8), (3.13, 5.8), (3.13, 4.89), (3.13, 3.98), (4.04, 3.98)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 5.8): [[], [(4.04, 6.71), (3.13, 6.71), (3.13, 5.8), (3.13, 4.89), (4.04, 4.89)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 6.71): [[], [(4.04, 7.62), (3.13, 7.62), (3.13, 6.71), (3.13, 5.8), (4.04, 5.8)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 7.62): [[], [(4.04, 8.53), (3.13, 8.53), (3.13, 7.62), (3.13, 6.71), (4.04, 6.71)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 8.53): [[], [(4.04, 9.44), (3.13, 9.44), (3.13, 8.53), (3.13, 7.62), (4.04, 7.62)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 9.44): [[], [(4.04, 10.35), (3.13, 10.35), (3.13, 9.44), (3.13, 8.53), (4.04, 8.53)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 10.35): [[], [(4.04, 11.26), (3.13, 11.26), (3.13, 10.35), (3.13, 9.44), (4.04, 9.44)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 11.26): [[], [(4.04, 12.17), (3.13, 12.17), (3.13, 11.26), (3.13, 10.35), (4.04, 10.35)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 12.17): [[], [(4.04, 13.08), (3.13, 13.08), (3.13, 12.17), (3.13, 11.26), (4.04, 11.26)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 13.08): [[], [(4.04, 13.99), (3.13, 13.99), (3.13, 13.08), (3.13, 12.17), (4.04, 12.17)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 13.99): [[], [(4.04, 14.9), (3.13, 14.9), (3.13, 13.99), (3.13, 13.08), (4.04, 13.08)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 14.9): [[], [(4.04, 15.81), (3.13, 15.81), (3.13, 14.9), (3.13, 13.99), (4.04, 13.99)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 15.81): [[], [(4.04, 16.72), (3.13, 16.72), (3.13, 15.81), (3.13, 14.9), (4.04, 14.9)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 16.72): [[], [(4.04, 17.63), (3.13, 17.63), (3.13, 16.72), (3.13, 15.81), (4.04, 15.81)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 17.63): [[], [(4.04, 18.54), (3.13, 18.54), (3.13, 17.63), (3.13, 16.72), (4.04, 16.72)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 18.54): [[], [(4.04, 19.45), (3.13, 19.45), (3.13, 18.54), (3.13, 17.63), (4.04, 17.63)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 19.45): [[], [(4.04, 20.36), (3.13, 20.36), (3.13, 19.45), (3.13, 18.54), (4.04, 18.54)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, ...
# {(4.04, 3.98): [[], [(4.04, 4.89), (4.95, 4.89), (4.95, 3.98)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 0, 0, 0, 0, 0], (4.04, 4.89): [[(3.18, 4.34), (3.4, 4.35), (3.54, 4.39), (3.56, 4.63), (3.74, 4.56), (3.95, 4.31)], [(4.04, 5.8), (3.13, 5.8), (3.13, 4.89), (3.13, 3.98), (4.04, 3.98)], [(3.56, 4.63), (3.56, 4.63), (3.74, 4.56), (3.18, 4.34), (3.95, 4.31), (3.18, 4.34), (3.54, 4.39), (3.95, 4.31)], 1, 1, 0, 0, 0], (4.04, 5.8): [[(3.67, 5.04), (3.74, 5.0)], [(4.04, 6.71), (3.13, 6.71), (3.13, 5.8), (3.13, 4.89), (4.04, 4.89)], [(3.67, 5.04), (3.67, 5.04), (3.67, 5.04), (3.67, 5.04), (3.74, 5.0), (3.67, 5.04), (3.67, 5.04), (3.74, 5.0)], 1, 1, 0, 0, 0], (4.04, 6.71): [[(3.69, 6.51), (3.89, 6.56), (4.0, 6.48)], [(4.04, 7.62), (3.13, 7.62), (3.13, 6.71), (3.13, 5.8), (4.04, 5.8)], [(3.69, 6.51), (3.69, 6.51), (3.89, 6.56), (3.69, 6.51), (4.0, 6.48), (3.69, 6.51), (3.69, 6.51), (4.0, 6.48)], 1, 1, 0, 0, 0], (4.04, 7.62): [[], [(4.04, 8.53), (3.13, 8.53), (3.13, 7.62), (3.13, 6.71), (4.04, 6.71)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 8.53): [[], [(4.04, 9.44), (3.13, 9.44), (3.13, 8.53), (3.13, 7.62), (4.04, 7.62)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 9.44): [[], [(4.04, 10.35), (3.13, 10.35), (3.13, 9.44), (3.13, 8.53), (4.04, 8.53)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 10.35): [[], [(4.04, 11.26), (3.13, 11.26), (3.13, 10.35), (3.13, 9.44), (4.04, 9.44)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 11.26): [[], [(4.04, 12.17), (3.13, 12.17), (3.13, 11.26), (3.13, 10.35), (4.04, 10.35)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 12.17): [[], [(4.04, 13.08), (3.13, 13.08), (3.13, 12.17), (3.13, 11.26), (4.04, 11.26)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 13.08): [[], [(4.04, 13.99), (3.13, 13.99), (3.13, 13.08), (3.13, 12.17), (4.04, 12.17)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 13.99): [[], [(4.04, 14.9), (3.13, 14.9), (3.13, 13.99), (3.13, 13.08), (4.04, 13.08)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 14.9): [[], [(4.04, 15.81), (3.13, 15.81), (3.13, 14.9), (3.13, 13.99), (4.04, 13.99)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 15.81): [[], [(4.04, 16.72), (3.13, 16.72), (3.13, 15.81), (3.13, 14.9), (4.04, 14.9)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 16.72): [[], [(4.04, 17.63), (3.13, 17.63), (3.13, 16.72), (3.13, 15.81), (4.04, 15.81)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 17.63): [[], [(4.04, 18.54), (3.13, 18.54), (3.13, 17.63), (3.13, 16.72), (4.04, 16.72)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 18.54): [[], [(4.04, 19.45), (3.13, 19.45), (3.13, 18.54), (3.13, 17.63), (4.04, 17.63)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 19.45): [[(3.37, 19.3), (3.57, 19.09)], [(4.04, 20.36), (3.13, 20.36), (3. ...
# Current Box: (4.04, 4.89)
# Cluster_id before calling clustering on box  (4.04, 4.89) : 1
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.04, 5.8)
# top point of  (4.04, 4.89) : (3.56, 4.63)
# bottom point of  (4.04, 5.8) : (3.67, 5.04)
# Distance between points: 0.42449970553582256
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (4.04, 5.8) 1
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.04, 6.71)
# top point of  (4.04, 5.8) : (3.67, 5.04)
# bottom point of  (4.04, 6.71) : (3.69, 6.51)
# Distance between points: 1.4701360481261587
# Boxes to merge or not: False
# To merge or not to merge first level top box False
# checking for j+1 box
# Calling for Second level for top box
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (4.95, 6.71)
# top_right point of  (4.04, 5.8) : (3.67, 5.04)
# bottom_left point of  (4.95, 6.71) : (4.28, 6.15)
# Distance between points: 1.266570171763097
# Boxes to merge or not: True
# To merge or not to merge top right level  True
# clustering id for 1st top right box 1
# calling clustering on (4.95, 6.71)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.95, 7.62)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (5.86, 7.62)
# top_right point of  (4.95, 6.71) : (4.41, 6.6)
# bottom_left point of  (5.86, 7.62) : (5.16, 6.93)
# Distance between points: 0.8193900170248598
# Boxes to merge or not: True
# To merge or not to merge top right level  True
# clustering id for 1st top right box 1
# calling clustering on (5.86, 7.62)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (5.86, 8.53)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (6.7700000000000005, 8.53)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (6.7700000000000005, 7.62)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (6.7700000000000005, 6.71)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (5.86, 6.71)
# bottom point of  (5.86, 7.62) : (5.16, 6.93)
# top point of  (5.86, 6.71) : (5.41, 6.07)
# Distance between points: 0.8956003573022954
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 1
# calling clustering on (5.86, 6.71)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (5.86, 7.62)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (6.7700000000000005, 7.62)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (6.7700000000000005, 6.71)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (6.7700000000000005, 5.8)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (5.86, 5.8)
# bottom point of  (5.86, 6.71) : (5.31, 5.86)
# top point of  (5.86, 5.8) : (5.69, 5.71)
# Distance between points: 0.4085339643163108
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 1
# calling clustering on (5.86, 5.8)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (5.86, 6.71)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (6.7700000000000005, 6.71)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (6.7700000000000005, 5.8)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (6.7700000000000005, 4.89)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (5.86, 4.89)
# bottom point of  (5.86, 5.8) : (5.4, 5.22)
# top point of  (5.86, 4.89) : (5.77, 4.88)
# Distance between points: 0.5024937810560438
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 1
# calling clustering on (5.86, 4.89)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (5.86, 5.8)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (6.7700000000000005, 5.8)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (6.7700000000000005, 4.89)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (6.7700000000000005, 3.9799999999999995)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (5.86, 3.9799999999999995)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.95, 3.9799999999999995)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.95, 4.89)
# left point of  (5.86, 4.89) : (5.08, 4.53)
# right point of  (4.95, 4.89) : (4.78, 4.3)
# Distance between points: 0.3780211634287161
# Boxes to merge or not: True
# To merge or not to merge left level   True
# clustering id for 1st left box 1
# calling clustering on (4.95, 4.89)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.95, 5.8)
# top point of  (4.95, 4.89) : (4.77, 4.66)
# bottom point of  (4.95, 5.8) : (4.29, 5.34)
# Distance between points: 0.832346081867392
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (4.95, 5.8) 1
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.95, 6.71)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (5.86, 6.71)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (5.86, 5.8)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (5.86, 4.89)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.95, 4.89)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.04, 4.89)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.04, 5.8)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.04, 6.71)
# top_left point of  (4.95, 5.8) : (4.29, 5.34)
# bottom_right point of  (4.04, 6.71) : (4.0, 6.48)
# Distance between points: 1.1763077828527708
# Boxes to merge or not: True
# To merge or not to merge up left level   True
# clustering id for 1st top left box 1
# calling clustering on (4.04, 6.71)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.04, 7.62)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (4.95, 7.62)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (4.95, 6.71)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (4.95, 5.8)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.04, 5.8)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (3.13, 5.8)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (3.13, 6.71)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (3.13, 7.62)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (5.86, 5.8)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (5.86, 4.89)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (5.86, 3.9799999999999995)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.95, 3.9799999999999995)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.04, 3.9799999999999995)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.04, 4.89)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.04, 5.8)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.95, 5.8)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.95, 4.89)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.95, 5.8)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.95, 6.71)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.95, 5.8)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.95, 6.71)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.95, 7.62)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.95, 6.71)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.95, 7.62)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.95, 8.53)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (5.86, 6.71)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (5.86, 5.8)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.95, 5.8)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.04, 5.8)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.04, 6.71)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.04, 7.62)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (4.95, 5.8)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (4.95, 4.89)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.04, 4.89)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (3.13, 4.89)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (3.13, 5.8)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (3.13, 6.71)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (4.95, 5.8)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (4.95, 4.89)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (4.95, 3.9799999999999995)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.04, 3.9799999999999995)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (3.13, 3.9799999999999995)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (3.13, 4.89)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (3.13, 5.8)
# Current Box: (4.04, 19.45)
# Cluster_id before calling clustering on box  (4.04, 19.45) : 2
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.04, 20.36)
# top point of  (4.04, 19.45) : (3.37, 19.3)
# bottom point of  (4.04, 20.36) : (3.55, 19.61)
# Distance between points: 0.3584689665786972
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (4.04, 20.36) 2
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.04, 21.27)
# top point of  (4.04, 20.36) : (3.81, 19.94)
# bottom point of  (4.04, 21.27) : (3.73, 20.48)
# Distance between points: 0.5458937625582464
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (4.04, 21.27) 2
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.04, 22.18)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (4.95, 22.18)
# top_right point of  (4.04, 21.27) : (3.78, 20.51)
# bottom_left point of  (4.95, 22.18) : (4.48, 21.38)
# Distance between points: 1.1166467659918227
# Boxes to merge or not: True
# To merge or not to merge top right level  True
# clustering id for 1st top right box 2
# calling clustering on (4.95, 22.18)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.95, 23.09)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (5.86, 23.09)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (5.86, 22.18)
# right point of  (4.95, 22.18) : (4.41, 21.57)
# left point of  (5.86, 22.18) : (5.43, 21.45)
# Distance between points: 1.027034566117421
# Boxes to merge or not: True
# To merge or not to merge right level  True
# clustering id for 1st right box 2
# calling clustering on (5.86, 22.18)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (5.86, 23.09)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (6.7700000000000005, 23.09)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (6.7700000000000005, 22.18)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (6.7700000000000005, 21.27)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (5.86, 21.27)
# bottom point of  (5.86, 22.18) : (5.43, 21.45)
# top point of  (5.86, 21.27) : (5.82, 21.11)
# Distance between points: 0.5173973328110616
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 2
# calling clustering on (5.86, 21.27)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (5.86, 22.18)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (6.7700000000000005, 22.18)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (6.7700000000000005, 21.27)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (6.7700000000000005, 20.36)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (5.86, 20.36)
# bottom point of  (5.86, 21.27) : (5.68, 20.68)
# top point of  (5.86, 20.36) : (5.47, 20.34)
# Distance between points: 0.3996248240537616
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 2
# calling clustering on (5.86, 20.36)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (5.86, 21.27)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (6.7700000000000005, 21.27)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (6.7700000000000005, 20.36)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (6.7700000000000005, 19.45)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (5.86, 19.45)
# bottom point of  (5.86, 20.36) : (5.82, 20.08)
# top point of  (5.86, 19.45) : (5.14, 19.35)
# Distance between points: 0.9976472322419364
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 2
# calling clustering on (5.86, 19.45)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (5.86, 20.36)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (6.7700000000000005, 20.36)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (6.7700000000000005, 19.45)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (6.7700000000000005, 18.54)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (5.86, 18.54)
# bottom point of  (5.86, 19.45) : (4.99, 18.8)
# top point of  (5.86, 18.54) : (5.76, 18.38)
# Distance between points: 0.8770974860299172
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 2
# calling clustering on (5.86, 18.54)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (5.86, 19.45)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (6.7700000000000005, 19.45)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (6.7700000000000005, 18.54)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (6.7700000000000005, 17.63)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (5.86, 17.63)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.95, 17.63)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.95, 18.54)
# left point of  (5.86, 18.54) : (5.76, 18.38)
# right point of  (4.95, 18.54) : (4.85, 18.35)
# Distance between points: 0.9104943712072031
# Boxes to merge or not: True
# To merge or not to merge left level   True
# clustering id for 1st left box 2
# calling clustering on (4.95, 18.54)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.95, 19.45)
# top point of  (4.95, 18.54) : (4.52, 18.42)
# bottom point of  (4.95, 19.45) : (4.22, 18.64)
# Distance between points: 0.3720215047547647
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (4.95, 19.45) 2
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.95, 20.36)
# top point of  (4.95, 19.45) : (4.27, 19.07)
# bottom point of  (4.95, 20.36) : (4.38, 19.65)
# Distance between points: 0.590338885725816
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (4.95, 20.36) 2
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.95, 21.27)
# top point of  (4.95, 20.36) : (4.09, 19.84)
# bottom point of  (4.95, 21.27) : (4.67, 20.4)
# Distance between points: 0.8062257748298541
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (4.95, 21.27) 2
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.95, 22.18)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (5.86, 22.18)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (5.86, 21.27)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (5.86, 20.36)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.95, 20.36)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.04, 20.36)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.04, 21.27)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.04, 22.18)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (5.86, 21.27)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (5.86, 20.36)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (5.86, 19.45)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.95, 19.45)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.04, 19.45)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.04, 20.36)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.04, 21.27)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (5.86, 20.36)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (5.86, 19.45)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (5.86, 18.54)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.95, 18.54)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.04, 18.54)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.04, 19.45)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.04, 20.36)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (5.86, 19.45)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (5.86, 18.54)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (5.86, 17.63)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.95, 17.63)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.04, 17.63)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.04, 18.54)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.04, 19.45)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.95, 19.45)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.95, 18.54)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.95, 19.45)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.95, 20.36)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.95, 19.45)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.95, 20.36)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.95, 21.27)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.95, 20.36)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.95, 21.27)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.95, 22.18)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.95, 21.27)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.95, 22.18)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.95, 23.09)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (5.86, 21.27)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.95, 21.27)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.04, 21.27)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.04, 22.18)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.04, 23.09)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (4.95, 21.27)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (4.95, 20.36)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.04, 20.36)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (3.13, 20.36)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (3.13, 21.27)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (3.13, 22.18)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (4.95, 21.27)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (4.95, 20.36)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (4.95, 19.45)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.04, 19.45)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (3.13, 19.45)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (3.13, 20.36)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (3.13, 21.27)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (4.95, 20.36)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (4.95, 19.45)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (4.95, 18.54)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.04, 18.54)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (3.13, 18.54)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (3.13, 19.45)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (3.13, 20.36)
# Current Box: (4.95, 3.98)
# Cluster_id before calling clustering on box  (4.95, 3.98) : 3
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (4.95, 4.89)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (5.86, 4.89)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (5.86, 3.98)
# right point of  (4.95, 3.98) : (4.22, 3.18)
# left point of  (5.86, 3.98) : (5.3, 3.64)
# Distance between points: 1.1738824472663352
# Boxes to merge or not: True
# To merge or not to merge right level  True
# clustering id for 1st right box 3
# calling clustering on (5.86, 3.98)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (5.86, 4.89)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (6.7700000000000005, 4.89)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (6.7700000000000005, 3.98)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (6.7700000000000005, 3.07)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (5.86, 3.07)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.95, 3.07)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.95, 3.98)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.95, 4.89)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (5.86, 3.07)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (4.95, 3.07)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (4.04, 3.07)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (4.04, 3.98)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (4.04, 4.89)
# Current Box: (6.77, 4.89)
# Cluster_id before calling clustering on box  (6.77, 4.89) : 4
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (6.77, 5.8)
# top point of  (6.77, 4.89) : (6.45, 4.83)
# bottom point of  (6.77, 5.8) : (6.46, 5.16)
# Distance between points: 0.33015148038438363
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (6.77, 5.8) 4
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (6.77, 6.71)
# top point of  (6.77, 5.8) : (6.59, 5.74)
# bottom point of  (6.77, 6.71) : (6.08, 6.28)
# Distance between points: 0.7427651041883967
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (6.77, 6.71) 4
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (6.77, 7.62)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (7.68, 7.62)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (7.68, 6.71)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (7.68, 5.8)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (6.77, 5.8)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (5.859999999999999, 5.8)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (5.859999999999999, 6.71)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (5.859999999999999, 7.62)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (7.68, 6.71)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (7.68, 5.8)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (7.68, 4.89)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (6.77, 4.89)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (5.859999999999999, 4.89)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (5.859999999999999, 5.8)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (5.859999999999999, 6.71)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (7.68, 5.8)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (7.68, 4.89)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (7.68, 3.9799999999999995)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (6.77, 3.9799999999999995)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (5.859999999999999, 3.9799999999999995)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (5.859999999999999, 4.89)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (5.859999999999999, 5.8)
# Current Box: (6.77, 18.54)
# Cluster_id before calling clustering on box  (6.77, 18.54) : 5
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (6.77, 19.45)
# top point of  (6.77, 18.54) : (6.1, 18.4)
# bottom point of  (6.77, 19.45) : (6.07, 18.84)
# Distance between points: 0.4410215414240002
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (6.77, 19.45) 5
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (6.77, 20.36)
# top point of  (6.77, 19.45) : (6.58, 19.26)
# bottom point of  (6.77, 20.36) : (6.09, 19.51)
# Distance between points: 0.5500909015790029
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (6.77, 20.36) 5
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (6.77, 21.27)
# top point of  (6.77, 20.36) : (6.11, 20.26)
# bottom point of  (6.77, 21.27) : (6.13, 20.93)
# Distance between points: 0.6702984409947538
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (6.77, 21.27) 5
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (6.77, 22.18)
# top point of  (6.77, 21.27) : (6.13, 20.93)
# bottom point of  (6.77, 22.18) : (6.39, 21.38)
# Distance between points: 0.5197114584074506
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (6.77, 22.18) 5
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (6.77, 23.09)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (7.68, 23.09)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (7.68, 22.18)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (7.68, 21.27)
# bottom_right point of  (6.77, 22.18) : (6.39, 21.38)
# top_left point of  (7.68, 21.27) : (6.8, 20.61)
# Distance between points: 0.8723531395025752
# Boxes to merge or not: True
# To merge or not to merge  down right level  True
# clustering id for 1st down right box 5
# calling clustering on (7.68, 21.27)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (7.68, 22.18)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (8.59, 22.18)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (8.59, 21.27)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (8.59, 20.36)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (7.68, 20.36)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (6.77, 20.36)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (6.77, 21.27)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (6.77, 22.18)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (6.77, 21.27)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (5.859999999999999, 21.27)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (5.859999999999999, 22.18)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (5.859999999999999, 23.09)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (7.68, 22.18)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (7.68, 21.27)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (7.68, 20.36)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (6.77, 20.36)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (5.859999999999999, 20.36)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (5.859999999999999, 21.27)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (5.859999999999999, 22.18)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (7.68, 21.27)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (7.68, 20.36)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (7.68, 19.45)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (6.77, 19.45)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (5.859999999999999, 19.45)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (5.859999999999999, 20.36)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (5.859999999999999, 21.27)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (7.68, 20.36)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (7.68, 19.45)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (7.68, 18.54)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (6.77, 18.54)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (5.859999999999999, 18.54)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (5.859999999999999, 19.45)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (5.859999999999999, 20.36)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (7.68, 19.45)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (7.68, 18.54)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (7.68, 17.63)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (6.77, 17.63)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (5.859999999999999, 17.63)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (5.859999999999999, 18.54)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (5.859999999999999, 19.45)
# Current Box: (7.68, 8.53)
# Cluster_id before calling clustering on box  (7.68, 8.53) : 6
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (7.68, 9.44)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (8.59, 9.44)
# top_right point of  (7.68, 8.53) : (7.5, 8.12)
# bottom_left point of  (8.59, 9.44) : (7.82, 8.54)
# Distance between points: 0.5280151512977636
# Boxes to merge or not: True
# To merge or not to merge top right level  True
# clustering id for 1st top right box 6
# calling clustering on (8.59, 9.44)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (8.59, 10.35)
# top point of  (8.59, 9.44) : (8.19, 9.37)
# bottom point of  (8.59, 10.35) : (7.93, 9.48)
# Distance between points: 0.2823118842698623
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (8.59, 10.35) 6
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (8.59, 11.26)
# top point of  (8.59, 10.35) : (7.93, 9.48)
# bottom point of  (8.59, 11.26) : (7.76, 10.52)
# Distance between points: 1.0538026380684373
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (8.59, 11.26) 6
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (8.59, 12.17)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (9.5, 12.17)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (9.5, 11.26)
# right point of  (8.59, 11.26) : (7.76, 10.52)
# left point of  (9.5, 11.26) : (9.35, 10.65)
# Distance between points: 1.5953056133543815
# Boxes to merge or not: False
# To merge or not to merge right level  False
# Calling for Second level for  right
# choosing 2nd level box right (10.41, 11.26)
# Second Level box: (10.41, 11.26)
# right point of  (9.5, 11.26) : (9.35, 10.65)
# left point of  (10.41, 11.26) : (9.57, 10.63)
# Distance between points: 0.22090722034374582
# Boxes to merge or not: True
# To merge or not to merge second level right  True
# New cluster_id for right box jplus1 (10.41, 11.26) 0
# Calling clustering on right box second level
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (10.41, 12.17)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (11.32, 12.17)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (11.32, 11.26)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (11.32, 10.35)
# bottom_right point of  (10.41, 11.26) : (9.89, 10.42)
# top_left point of  (11.32, 10.35) : (10.45, 10.33)
# Distance between points: 0.567186036499488
# Boxes to merge or not: True
# To merge or not to merge  down right level  True
# clustering id for 1st down right box 0
# calling clustering on (11.32, 10.35)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (11.32, 11.26)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (12.23, 11.26)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (12.23, 10.35)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (12.23, 9.44)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (11.32, 9.44)
# bottom point of  (11.32, 10.35) : (10.51, 10.03)
# top point of  (11.32, 9.44) : (10.5, 8.77)
# Distance between points: 1.2600396819148194
# ...
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (23.15, 5.8)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (22.24, 5.8)
# bottom point of  (22.24, 6.71) : (21.54, 6.08)
# top point of  (22.24, 5.8) : (21.37, 5.64)
# Distance between points: 0.4716990566028299
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 16
# calling clustering on (22.24, 5.8)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (22.24, 6.71)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (23.15, 6.71)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (23.15, 5.8)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (23.15, 4.89)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (22.24, 4.89)
# bottom point of  (22.24, 5.8) : (21.45, 4.9)
# top point of  (22.24, 4.89) : (21.49, 4.07)
# Distance between points: 0.8309632964216891
# Boxes to merge or not: True
# To merge or not to merge  down level  True
# clustering id for 1st down box 16
# calling clustering on (22.24, 4.89)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (22.24, 5.8)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (23.15, 5.8)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (23.15, 4.89)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (23.15, 3.9799999999999995)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (22.24, 3.9799999999999995)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (21.33, 3.9799999999999995)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (21.33, 4.89)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (21.33, 5.8)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (21.33, 4.89)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (21.33, 5.8)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (21.33, 6.71)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (21.33, 5.8)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (21.33, 6.71)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (21.33, 7.62)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (22.24, 5.8)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (21.33, 5.8)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (20.419999999999998, 5.8)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (20.419999999999998, 6.71)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (20.419999999999998, 7.62)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (22.24, 6.71)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (22.24, 5.8)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (22.24, 4.89)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (21.33, 4.89)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (20.419999999999998, 4.89)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (20.419999999999998, 5.8)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (20.419999999999998, 6.71)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (22.24, 5.8)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (22.24, 4.89)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (22.24, 3.9799999999999995)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (21.33, 3.9799999999999995)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (20.419999999999998, 3.9799999999999995)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (20.419999999999998, 4.89)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (20.419999999999998, 5.8)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (22.24, 4.89)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (22.24, 3.98)
# right point of  (21.33, 3.98) : (21.19, 3.6)
# left point of  (22.24, 3.98) : (21.53, 3.74)
# Distance between points: 0.36769552621700463
# Boxes to merge or not: True
# To merge or not to merge right level  True
# clustering id for 1st right box 16
# calling clustering on (22.24, 3.98)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (22.24, 4.89)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (23.15, 4.89)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (23.15, 3.98)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (23.15, 3.07)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (22.24, 3.07)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (21.33, 3.07)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (21.33, 3.98)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (21.33, 4.89)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (22.24, 3.07)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (21.33, 3.07)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (20.419999999999998, 3.07)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (20.419999999999998, 3.98)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (20.419999999999998, 4.89)
# Current Box: (21.33, 18.54)
# Cluster_id before calling clustering on box  (21.33, 18.54) : 17
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (21.33, 19.45)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (22.24, 19.45)
# top_right point of  (21.33, 18.54) : (20.71, 18.29)
# bottom_left point of  (22.24, 19.45) : (21.43, 19.14)
# Distance between points: 1.113956911195402
# Boxes to merge or not: True
# To merge or not to merge top right level  True
# clustering id for 1st top right box 17
# calling clustering on (22.24, 19.45)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (22.24, 20.36)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (23.15, 20.36)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (23.15, 19.45)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (23.15, 18.54)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (22.24, 18.54)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (21.33, 18.54)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (21.33, 19.45)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (21.33, 20.36)
# top_left point of  (22.24, 19.45) : (21.43, 19.14)
# bottom_right point of  (21.33, 20.36) : (21.09, 19.99)
# Distance between points: 0.9154780172128637
# Boxes to merge or not: True
# To merge or not to merge up left level   True
# clustering id for 1st top left box 17
# calling clustering on (21.33, 20.36)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (21.33, 21.27)
# top point of  (21.33, 20.36) : (20.81, 20.07)
# bottom point of  (21.33, 21.27) : (20.67, 20.82)
# Distance between points: 0.7629547824084985
# Boxes to merge or not: True
# To merge or not to merge first level top box True
# Calling clustering on 1st level top box (21.33, 21.27) 17
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (21.33, 22.18)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (22.24, 22.18)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (22.24, 21.27)
# right point of  (21.33, 21.27) : (20.83, 21.22)
# left point of  (22.24, 21.27) : (21.38, 20.75)
# Distance between points: 0.7234638899074367
# Boxes to merge or not: True
# To merge or not to merge right level  True
# clustering id for 1st right box 17
# calling clustering on (22.24, 21.27)
# Flag details before checking flag  1 1
# Inside first if
# Checking for top box
# First level top box (22.24, 22.18)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (23.15, 22.18)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (23.15, 21.27)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (23.15, 20.36)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (22.24, 20.36)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (21.33, 20.36)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (21.33, 21.27)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (21.33, 22.18)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (22.24, 20.36)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (21.33, 20.36)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (20.419999999999998, 20.36)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (20.419999999999998, 21.27)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (20.419999999999998, 22.18)
# Checking for up right
# checking for top right 1st  level box
# 1st level top right level =  (22.24, 21.27)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (22.24, 20.36)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (22.24, 19.45)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (21.33, 19.45)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (20.419999999999998, 19.45)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (20.419999999999998, 20.36)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (20.419999999999998, 21.27)
# Checking for right
# checking for right 1st  level box
# 1st level right level =  (22.24, 18.54)
# Checking for down right
# checking for down right 1st  level box
# 1st level down right box =  (22.24, 17.63)
# Checking for down
# checking for down 1st  level box
# 1st level down level =  (21.33, 17.63)
# Checking for down left
# checking for left down 1st  level box
# 1st level down left box =  (20.419999999999998, 17.63)
# Checking for left
# checking for left 1st  level box
# 1st level left box =  (20.419999999999998, 18.54)
# checking for up left
# checking for up left 1st  level box
# 1st level up left box =  (20.419999999999998, 19.45)
# {(4.04, 3.98): [[], [(4.04, 4.89), (4.95, 4.89), (4.95, 3.98)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 0, 0, 0, 0, 0], (4.04, 4.89): [[(3.18, 4.34), (3.4, 4.35), (3.54, 4.39), (3.56, 4.63), (3.74, 4.56), (3.95, 4.31)], [(4.04, 5.8), (3.13, 5.8), (3.13, 4.89), (3.13, 3.98), (4.04, 3.98)], [(3.56, 4.63), (3.56, 4.63), (3.74, 4.56), (3.18, 4.34), (3.95, 4.31), (3.18, 4.34), (3.54, 4.39), (3.95, 4.31)], 1, 1, 1, 1, 1], (4.04, 5.8): [[(3.67, 5.04), (3.74, 5.0)], [(4.04, 6.71), (3.13, 6.71), (3.13, 5.8), (3.13, 4.89), (4.04, 4.89)], [(3.67, 5.04), (3.67, 5.04), (3.67, 5.04), (3.67, 5.04), (3.74, 5.0), (3.67, 5.04), (3.67, 5.04), (3.74, 5.0)], 1, 1, 1, 1, 1], (4.04, 6.71): [[(3.69, 6.51), (3.89, 6.56), (4.0, 6.48)], [(4.04, 7.62), (3.13, 7.62), (3.13, 6.71), (3.13, 5.8), (4.04, 5.8)], [(3.69, 6.51), (3.69, 6.51), (3.89, 6.56), (3.69, 6.51), (4.0, 6.48), (3.69, 6.51), (3.69, 6.51), (4.0, 6.48)], 1, 1, 1, 1, 1], (4.04, 7.62): [[], [(4.04, 8.53), (3.13, 8.53), (3.13, 7.62), (3.13, 6.71), (4.04, 6.71)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 8.53): [[], [(4.04, 9.44), (3.13, 9.44), (3.13, 8.53), (3.13, 7.62), (4.04, 7.62)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 9.44): [[], [(4.04, 10.35), (3.13, 10.35), (3.13, 9.44), (3.13, 8.53), (4.04, 8.53)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 10.35): [[], [(4.04, 11.26), (3.13, 11.26), (3.13, 10.35), (3.13, 9.44), (4.04, 9.44)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 11.26): [[], [(4.04, 12.17), (3.13, 12.17), (3.13, 11.26), (3.13, 10.35), (4.04, 10.35)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 12.17): [[], [(4.04, 13.08), (3.13, 13.08), (3.13, 12.17), (3.13, 11.26), (4.04, 11.26)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 13.08): [[], [(4.04, 13.99), (3.13, 13.99), (3.13, 13.08), (3.13, 12.17), (4.04, 12.17)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 13.99): [[], [(4.04, 14.9), (3.13, 14.9), (3.13, 13.99), (3.13, 13.08), (4.04, 13.08)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 14.9): [[], [(4.04, 15.81), (3.13, 15.81), (3.13, 14.9), (3.13, 13.99), (4.04, 13.99)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 15.81): [[], [(4.04, 16.72), (3.13, 16.72), (3.13, 15.81), (3.13, 14.9), (4.04, 14.9)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 16.72): [[], [(4.04, 17.63), (3.13, 17.63), (3.13, 16.72), (3.13, 15.81), (4.04, 15.81)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 17.63): [[], [(4.04, 18.54), (3.13, 18.54), (3.13, 17.63), (3.13, 16.72), (4.04, 16.72)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 18.54): [[], [(4.04, 19.45), (3.13, 19.45), (3.13, 18.54), (3.13, 17.63), (4.04, 17.63)], [(-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999), (-999, -999)], 1, 0, 0, 0, 0], (4.04, 19.45): [[(3.37, 19.3), (3.57, 19.09)], [(4.04, 20.36), (3.13, 20.36), (3. ...
# Counter({0: 346, 2: 13, 14: 12, 1: 10, 13: 10, 16: 8, 11: 7, 5: 6, 6: 5, 17: 5, 8: 4, 4: 3, 7: 3, 10: 3, 3: 2, 15: 2, 9: 1, 12: 1})
# --- 1.245140552520752 seconds in supercube_dbscan---
